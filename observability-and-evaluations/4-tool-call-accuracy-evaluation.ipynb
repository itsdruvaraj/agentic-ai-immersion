# %% [markdown]
# # 🎯 Tool Call Accuracy Evaluation
#
# This notebook demonstrates how to evaluate **tool call accuracy** using Microsoft Foundry's built-in evaluators. Tool Call Accuracy measures whether an agent correctly identifies and calls the appropriate tools with proper parameters.
#
# ## 🎯 Learning Objectives
#
# 1. **Understand tool call accuracy** evaluation concepts
# 2. **Define tool definitions** for evaluation
# 3. **Create test scenarios** with expected tool calls
# 4. **Evaluate** whether agents make correct tool choices
#
# ## 💼 Industry Use Case: Banking Operations Tool Selection
#
# In banking, agents must select the correct tool for each request:
# - **Wire transfers** require `initiate_wire_transfer` (not `account_balance`)
# - **Account inquiries** require `get_account_balance` (not `execute_trade`)
# - **Fraud alerts** require `report_suspicious_activity`
#
# **Incorrect tool selection can lead to:**
# - Unauthorized transactions
# - Regulatory violations
# - Customer complaints
# - Financial losses
#
# ### ⚠️ Disclaimer
# > **This is a demonstration with simulated data.** In production, actual banking API calls would be validated against compliance requirements.

# %% [markdown]
# ## 🔐 Authentication Setup
#
# Before running this notebook, authenticate with Azure CLI:
#
# ```bash
# az login --use-device-code
# ```

# %% [markdown]
# ## 1. Environment Setup

# %%
import json
import os
import time
from pathlib import Path
from pprint import pprint
from dotenv import load_dotenv

# Load environment variables
notebook_path = Path().absolute()
env_path = notebook_path.parent / '.env'
load_dotenv(env_path)

# Verify required environment variables
project_endpoint = os.environ.get("AI_FOUNDRY_PROJECT_ENDPOINT")
tenant_id = os.environ.get("TENANT_ID")
model_deployment = os.environ.get("AZURE_AI_MODEL_DEPLOYMENT_NAME", "gpt-4o")

if not project_endpoint:
    raise ValueError("🚨 AI_FOUNDRY_PROJECT_ENDPOINT not set in .env")

print(f"🔑 Tenant ID: {tenant_id}")
print(f"📍 Project Endpoint: {project_endpoint[:50]}...")
print(f"🤖 Model Deployment: {model_deployment}")
# Out:
# 🔑 Tenant ID: 16b3c013-d300-468d-ac64-7eda0820b6d3
# 📍 Project Endpoint: https://kd-foundry.services.ai.azure.com/api/proje...
# 🤖 Model Deployment: gpt-4o

# %% [markdown]
# ## 2. Initialize AI Project Client

# %%
from azure.identity import AzureCliCredential
from azure.ai.projects import AIProjectClient
from openai.types.evals.create_eval_jsonl_run_data_source_param import (
    CreateEvalJSONLRunDataSourceParam,
    SourceFileContent,
    SourceFileContentContent,
)
from openai.types.eval_create_params import DataSourceConfigCustom

# Initialize credentials and clients
credential = AzureCliCredential(tenant_id=tenant_id)
project_client = AIProjectClient(endpoint=project_endpoint, credential=credential)
openai_client = project_client.get_openai_client()

print("✅ AIProjectClient initialized")
print("✅ OpenAI client retrieved for evaluations")
# Out:
# ✅ AIProjectClient initialized
# ✅ OpenAI client retrieved for evaluations

# %% [markdown]
# ## 3. Define Banking Tool Definitions
#
# These are the tools our banking agent should have access to. The evaluator will check if the agent selects the correct tool for each query.

# %%
# Banking tool definitions for FSI scenarios
banking_tool_definitions = [
    {
        "type": "function",
        "name": "get_account_balance",
        "description": "Retrieves the current balance for a customer's bank account",
        "parameters": {
            "type": "object",
            "properties": {
                "account_number": {"type": "string", "description": "The account number to check"},
                "account_type": {"type": "string", "description": "Type of account: checking, savings, or investment"}
            },
        },
    },
    {
        "type": "function",
        "name": "initiate_wire_transfer",
        "description": "Initiates a wire transfer from one account to another",
        "parameters": {
            "type": "object",
            "properties": {
                "from_account": {"type": "string", "description": "Source account number"},
                "to_account": {"type": "string", "description": "Destination account number"},
                "amount": {"type": "number", "description": "Amount to transfer in USD"},
                "memo": {"type": "string", "description": "Transfer description or memo"}
            },
        },
    },
    {
        "type": "function",
        "name": "get_transaction_history",
        "description": "Retrieves recent transactions for a bank account",
        "parameters": {
            "type": "object",
            "properties": {
                "account_number": {"type": "string", "description": "The account number"},
                "days": {"type": "integer", "description": "Number of days of history to retrieve"}
            },
        },
    },
    {
        "type": "function",
        "name": "report_suspicious_activity",
        "description": "Reports suspicious or potentially fraudulent activity on an account",
        "parameters": {
            "type": "object",
            "properties": {
                "account_number": {"type": "string", "description": "The affected account number"},
                "description": {"type": "string", "description": "Description of the suspicious activity"},
                "urgency": {"type": "string", "description": "Urgency level: low, medium, high, critical"}
            },
        },
    },
    {
        "type": "function",
        "name": "apply_for_loan",
        "description": "Initiates a loan application process",
        "parameters": {
            "type": "object",
            "properties": {
                "loan_type": {"type": "string", "description": "Type of loan: mortgage, auto, personal"},
                "amount": {"type": "number", "description": "Requested loan amount"},
                "term_months": {"type": "integer", "description": "Loan term in months"}
            },
        },
    },
]

print(f"✅ Defined {len(banking_tool_definitions)} banking tools:")
for tool in banking_tool_definitions:
    print(f"   • {tool['name']}: {tool['description'][:50]}...")
# Out:
# ✅ Defined 5 banking tools:
#    • get_account_balance: Retrieves the current balance for a customer's ban...
#    • initiate_wire_transfer: Initiates a wire transfer from one account to anot...
#    • get_transaction_history: Retrieves recent transactions for a bank account...
#    • report_suspicious_activity: Reports suspicious or potentially fraudulent activ...
#    • apply_for_loan: Initiates a loan application process...

# %% [markdown]
# ## 4. Create Test Scenarios
#
# We'll create test scenarios that simulate:
# 1. **Correct tool selection** - Agent picks the right tool
# 2. **Correct parameters** - Agent extracts proper values from query
# 3. **Multi-tool scenarios** - Agent uses multiple tools when needed

# %%
# Scenario 1: Simple balance inquiry - should call get_account_balance
query1 = "What's the current balance in my checking account CHK-12345?"
tool_calls1 = [
    {
        "type": "tool_call",
        "tool_call_id": "call_balance_1",
        "name": "get_account_balance",
        "arguments": {"account_number": "CHK-12345", "account_type": "checking"},
    }
]

# Scenario 2: Wire transfer request - should call initiate_wire_transfer
query2 = "Please transfer $5,000 from my account ACC-001 to ACC-002 for the office rent payment."
tool_calls2 = [
    {
        "type": "tool_call",
        "tool_call_id": "call_transfer_1",
        "name": "initiate_wire_transfer",
        "arguments": {
            "from_account": "ACC-001",
            "to_account": "ACC-002",
            "amount": 5000,
            "memo": "office rent payment"
        },
    }
]

# Scenario 3: Fraud report - should call report_suspicious_activity
query3 = "I noticed unauthorized charges on account SAV-99999. There's a $2000 ATM withdrawal I didn't make. This is urgent!"
tool_calls3 = [
    {
        "type": "tool_call",
        "tool_call_id": "call_fraud_1",
        "name": "report_suspicious_activity",
        "arguments": {
            "account_number": "SAV-99999",
            "description": "Unauthorized ATM withdrawal of $2000",
            "urgency": "high"
        },
    }
]

# Scenario 4: Multi-step request - should call multiple tools
query4 = "Show me my last 30 days of transactions for account CHK-55555, and also check the balance."
tool_calls4 = [
    {
        "type": "tool_call",
        "tool_call_id": "call_history_1",
        "name": "get_transaction_history",
        "arguments": {"account_number": "CHK-55555", "days": 30},
    },
    {
        "type": "tool_call",
        "tool_call_id": "call_balance_2",
        "name": "get_account_balance",
        "arguments": {"account_number": "CHK-55555", "account_type": "checking"},
    }
]

# Scenario 5: Loan application - should call apply_for_loan
query5 = "I'd like to apply for a $25,000 personal loan with a 36-month term."
tool_calls5 = [
    {
        "type": "tool_call",
        "tool_call_id": "call_loan_1",
        "name": "apply_for_loan",
        "arguments": {
            "loan_type": "personal",
            "amount": 25000,
            "term_months": 36
        },
    }
]

print("✅ Created 5 test scenarios:")
print("   1. Balance inquiry → get_account_balance")
print("   2. Wire transfer → initiate_wire_transfer")
print("   3. Fraud report → report_suspicious_activity")
print("   4. Multi-tool request → get_transaction_history + get_account_balance")
print("   5. Loan application → apply_for_loan")
# Out:
# ✅ Created 5 test scenarios:
#    1. Balance inquiry → get_account_balance
#    2. Wire transfer → initiate_wire_transfer
#    3. Fraud report → report_suspicious_activity
#    4. Multi-tool request → get_transaction_history + get_account_balance
#    5. Loan application → apply_for_loan

# %% [markdown]
# ## 5. Configure Tool Call Accuracy Evaluation
#
# The `builtin.tool_call_accuracy` evaluator checks:
# - Was the correct tool selected?
# - Were the parameters extracted correctly?
# - Were all required tools called?

# %%
# Define data source config for tool call accuracy evaluation
data_source_config = DataSourceConfigCustom(
    type="custom",
    item_schema={
        "type": "object",
        "properties": {
            "query": {"anyOf": [{"type": "string"}, {"type": "array", "items": {"type": "object"}}]},
            "tool_definitions": {
                "anyOf": [{"type": "object"}, {"type": "array", "items": {"type": "object"}}]
            },
            "tool_calls": {"anyOf": [{"type": "object"}, {"type": "array", "items": {"type": "object"}}]},
            "response": {"anyOf": [{"type": "string"}, {"type": "array", "items": {"type": "object"}}]},
        },
        "required": ["query", "tool_definitions"],
    },
    include_sample_schema=True,
)

# Testing criteria using the Tool Call Accuracy evaluator
testing_criteria = [
    {
        "type": "azure_ai_evaluator",
        "name": "tool_call_accuracy",
        "evaluator_name": "builtin.tool_call_accuracy",
        "initialization_parameters": {"deployment_name": model_deployment},
        "data_mapping": {
            "query": "{{item.query}}",
            "tool_definitions": "{{item.tool_definitions}}",
            "tool_calls": "{{item.tool_calls}}",
            "response": "{{item.response}}",
        },
    }
]

print("✅ Evaluation criteria configured:")
print("   • Evaluator: builtin.tool_call_accuracy")
print("   • Data fields: query, tool_definitions, tool_calls, response")
# Out:
# ✅ Evaluation criteria configured:
#    • Evaluator: builtin.tool_call_accuracy
#    • Data fields: query, tool_definitions, tool_calls, response

# %% [markdown]
# ## 6. Create Evaluation Object

# %%
# Create evaluation object
eval_object = openai_client.evals.create(
    name="Banking Tool Call Accuracy Evaluation",
    data_source_config=data_source_config,
    testing_criteria=testing_criteria,  # type: ignore
)

print(f"✅ Evaluation created")
print(f"   ID: {eval_object.id}")
print(f"   Name: {eval_object.name}")
# Out:
# ✅ Evaluation created
#    ID: eval_e28e53768edc4252bd1820aa9a454190
#    Name: Banking Tool Call Accuracy Evaluation

# %% [markdown]
# ## 7. Run Evaluation with Test Data

# %%
# Create evaluation run with inline test data
eval_run = openai_client.evals.runs.create(
    eval_id=eval_object.id,
    name="Banking Tool Call Accuracy Run",
    metadata={"team": "fsi-banking", "scenario": "tool-accuracy-v1"},
    data_source=CreateEvalJSONLRunDataSourceParam(
        type="jsonl",
        source=SourceFileContent(
            type="file_content",
            content=[
                # Scenario 1: Balance inquiry
                SourceFileContentContent(
                    item={
                        "query": query1,
                        "tool_definitions": banking_tool_definitions,
                        "tool_calls": tool_calls1,
                        "response": None,
                    }
                ),
                # Scenario 2: Wire transfer
                SourceFileContentContent(
                    item={
                        "query": query2,
                        "tool_definitions": banking_tool_definitions,
                        "tool_calls": tool_calls2,
                        "response": None,
                    }
                ),
                # Scenario 3: Fraud report
                SourceFileContentContent(
                    item={
                        "query": query3,
                        "tool_definitions": banking_tool_definitions,
                        "tool_calls": tool_calls3,
                        "response": None,
                    }
                ),
                # Scenario 4: Multi-tool request
                SourceFileContentContent(
                    item={
                        "query": query4,
                        "tool_definitions": banking_tool_definitions,
                        "tool_calls": tool_calls4,
                        "response": None,
                    }
                ),
                # Scenario 5: Loan application
                SourceFileContentContent(
                    item={
                        "query": query5,
                        "tool_definitions": banking_tool_definitions,
                        "tool_calls": tool_calls5,
                        "response": None,
                    }
                ),
            ]
        ),
    ),
)

print(f"🚀 Evaluation run created")
print(f"   Run ID: {eval_run.id}")
print(f"   Status: {eval_run.status}")
# Out:
# 🚀 Evaluation run created
#    Run ID: evalrun_15a60026a23442048ebae96960b6ad93
#    Status: in_progress

# %%
# Poll for evaluation completion
print("⏳ Waiting for evaluation to complete...")
print("-" * 40)

while True:
    eval_run = openai_client.evals.runs.retrieve(
        run_id=eval_run.id,
        eval_id=eval_object.id
    )
    print(f"   Status: {eval_run.status}")
    
    if eval_run.status == "completed" or eval_run.status == "failed":
        break
    
    time.sleep(5)

if eval_run.status == "completed":
    print("\n✅ Evaluation completed successfully!")
else:
    print("\n❌ Evaluation failed.")
# Out:
# ⏳ Waiting for evaluation to complete...
# ----------------------------------------
#    Status: in_progress
#    Status: in_progress
#    Status: in_progress
#    Status: in_progress
#    Status: completed
#
# ✅ Evaluation completed successfully!

# %% [markdown]
# ## 8. Analyze Evaluation Results

# %%
if eval_run.status == "completed":
    print("\n" + "=" * 60)
    print("📊 TOOL CALL ACCURACY EVALUATION RESULTS")
    print("=" * 60)
    
    # Display result counts
    print(f"\n📈 Result Counts: {eval_run.result_counts}")
    
    # Get output items
    output_items = list(
        openai_client.evals.runs.output_items.list(
            run_id=eval_run.id,
            eval_id=eval_object.id
        )
    )
    
    print(f"\n📝 SCENARIOS EVALUATED: {len(output_items)}")
    print("-" * 60)
    
    # Display results for each scenario
    scenario_names = [
        "Balance Inquiry",
        "Wire Transfer",
        "Fraud Report",
        "Multi-Tool Request",
        "Loan Application"
    ]
    
    for i, item in enumerate(output_items):
        scenario = scenario_names[i] if i < len(scenario_names) else f"Scenario {i+1}"
        print(f"\n🔹 {scenario}:")
        print(f"   Status: {item.status}")
        if hasattr(item, 'results') and item.results:
            for result in item.results:
                print(f"   Score: {result.score if hasattr(result, 'score') else 'N/A'}")
    
    # Display report URL
    if eval_run.report_url:
        print(f"\n🔗 Full Report URL: {eval_run.report_url}")
    
    print("\n" + "-" * 60)
    print("📋 Detailed Results:")
    print("-" * 60)
    pprint(output_items)
else:
    print("\n❌ Cannot display results - evaluation did not complete.")
    if eval_run.report_url:
        print(f"🔗 Check report for details: {eval_run.report_url}")
# Out:
# ============================================================
# 📊 TOOL CALL ACCURACY EVALUATION RESULTS
# ============================================================
#
# 📈 Result Counts: ResultCounts(errored=0, failed=0, passed=5, total=5)
# 📝 SCENARIOS EVALUATED: 5
# ------------------------------------------------------------
#
# 🔹 Balance Inquiry:
#    Status: completed
#    Score: 5.0
#
# 🔹 Wire Transfer:
#    Status: completed
#    Score: 5.0
#
# 🔹 Fraud Report:
#    Status: completed
#    Score: 5.0
#
# 🔹 Multi-Tool Request:
#    Status: completed
#    Score: 5.0
#
# 🔹 Loan Application:
#    Status: completed
#    Score: 5.0
#
# 🔗 Full Report URL: https://ai.azure.com/nextgen/r/_zjmgq_gTsKOGNFN6JSXjw,rg-kd-foundry,,kd-foundry,proj-kd/build/evaluations/eval_e28e53768edc4252bd1820aa9a454190/run/evalrun_15a60026a23442048ebae96960b6ad93
#
# ------------------------------------------------------------
# 📋 Detailed Results:
# ------------------------------------------------------------
# [OutputItemListResponse(id='1', created_at=1778563239, datasource_item={'query': "What's the current balance in my checking account CHK-12345?", 'tool_definitions': [{'type': 'function', 'name': 'get_account_balance', 'description': "Retrieves the current balance for a customer's bank account", 'parameters': {'type': 'object', 'properties': {'account_number': {'type': 'string', 'description': 'The account number to check'}, 'account_type': {'type': 'string', 'description': 'Type of account: checking, savings, or investment'}}}}, {'type': 'function', 'name': 'initiate_wire_transfer', 'description': 'Initiates a wire transfer from one account to another', 'parameters': {'type': 'object', 'properties': {'from_account': {'type': 'string', 'description': 'Source account number'}, 'to_account': {'type': 'string', 'description': 'Destination account number'}, 'amount': {'type': 'number', 'description': 'Amount to transfer in USD'}, 'memo': {'type': 'string', 'description': 'Transfer description or memo'}}}}, {'type': 'function', 'name': 'get_transaction_history', 'description': 'Retrieves recent transactions for a bank account', 'parameters': {'type': 'object', 'properties': {'account_number': {'type': 'string', 'description': 'The account number'}, 'days': {'type': 'integer', 'description': 'Number of days of history to retrieve'}}}}, {'type': 'function', 'name': 'report_suspicious_activity', 'description': 'Reports suspicious or potentially fraudulent activity on an account', 'parameters': {'type': 'object', 'properties': {'account_number': {'type': 'string', 'description': 'The affected account number'}, 'description': {'type': 'string', 'description': 'Description of the suspicious activity'}, 'urgency': {'type': 'string', 'description': 'Urgency level: low, medium, high, critical'}}}}, {'type': 'function', 'name': 'apply_for_loan', 'description': 'Initiates a loan application process', 'parameters': {'type': 'object', 'properties': {'loan_type': {'type': 'string', 'description': 'Type of loan: mortgage, auto, personal'}, 'amount': {'type': 'number', 'description': 'Requested loan amount'}, 'term_months': {'type': 'integer', 'description': 'Loan term in months'}}}}], 'tool_calls': [{'type': 'tool_call', 'tool_call_id': 'call_balance_1', 'name': 'get_account_balance', 'arguments': {'account_number': 'CHK-12345', 'account_type': 'checking'}}], 'response': None}, datasource_item_id=0, eval_id='eval_e28e53768edc4252bd1820aa9a454190', object='eval.run.output_item', results=[Result(name='tool_call_accuracy', passed=True, score=5.0, sample=None, type='azure_ai_evaluator', metric='tool_call_accuracy', label='pass', reason="Let's think step by step: The user's last query was about checking the current balance in their checking account with account number CHK-12345. The relevant tool for this query, according to the tool definitions, is 'get_account_balance', which retrieves the current balance for a customer's bank account. The tool call made in the TOOL CALLS TO BE EVALUATED section correctly uses this tool with the parameters 'account_number' set to 'CHK-12345' and 'account_type' set to 'checking', both of which are grounded in the user's query. There are no unnecessary duplicate tool calls, and no errors were reported in the execution of the tool call. Therefore, the tool call was fully relevant, efficient, and executed without issues, making it an optimal solution.", threshold=3)], run_id='evalrun_15a60026a23442048ebae96960b6ad93', sample=Sample(error=None, finish_reason='', input=[], max_completion_tokens=None, model='', output=[], seed=None, temperature=None, top_p=None, usage=None), status='completed'),
#  OutputItemListResponse(id='2', created_at=1778563239, datasource_item={'query': 'Please transfer $5,000 from my account ACC-001 to ACC-002 for the office rent payment.', 'tool_definitions': [{'type': 'function', 'name': 'get_account_balance', 'description': "Retrieves the current balance for a customer's bank account", 'parameters': {'type': 'object', 'properties': {'account_number': {'type': 'string', 'description': 'The account number to check'}, 'account_type': {'type': 'string', 'description': 'Type of account: checking, savings, or investment'}}}}, {'type': 'function', 'name': 'initiate_wire_transfer', 'description': 'Initiates a wire transfer from one account to another', 'parameters': {'type': 'object', 'properties': {'from_account': {'type': 'string', 'description': 'Source account number'}, 'to_account': {'type': 'string', 'description': 'Destination account number'}, 'amount': {'type': 'number', 'description': 'Amount to transfer in USD'}, 'memo': {'type': 'string', 'description': 'Transfer description or memo'}}}}, {'type': 'function', 'name': 'get_transaction_history', 'description': 'Retrieves recent transactions for a bank account', 'parameters': {'type': 'object', 'properties': {'account_number': {'type': 'string', 'description': 'The account number'}, 'days': {'type': 'integer', 'description': 'Number of days of history to retrieve'}}}}, {'type': 'function', 'name': 'report_suspicious_activity', 'description': 'Reports suspicious or potentially fraudulent activity on an account', 'parameters': {'type': 'object', 'properties': {'account_number': {'type': 'string', 'description': 'The affected account number'}, 'description': {'type': 'string', 'description': 'Description of the suspicious activity'}, 'urgency': {'type': 'string', 'description': 'Urgency level: low, medium, high, critical'}}}}, {'type': 'function', 'name': 'apply_for_loan', 'description': 'Initiates a loan application process', 'parameters': {'type': 'object', 'properties': {'loan_type': {'type': 'string', 'description': 'Type of loan: mortgage, auto, personal'}, 'amount': {'type': 'number', 'description': 'Requested loan amount'}, 'term_months': {'type': 'integer', 'description': 'Loan term in months'}}}}], 'tool_calls': [{'type': 'tool_call', 'tool_call_id': 'call_transfer_1', 'name': 'initiate_wire_transfer', 'arguments': {'from_account': 'ACC-001', 'to_account': 'ACC-002', 'amount': 5000, 'memo': 'office rent payment'}}], 'response': None}, datasource_item_id=1, eval_id='eval_e28e53768edc4252bd1820aa9a454190', object='eval.run.output_item', results=[Result(name='tool_call_accuracy', passed=True, score=5.0, sample=None, type='azure_ai_evaluator', metric='tool_call_accuracy', label='pass', reason="Let's think step by step: The user's last query was to transfer $5,000 from account ACC-001 to ACC-002 for office rent payment. The relevant tool available for this task is 'initiate_wire_transfer', which is defined to handle such transactions. The tool call made by the agent matches this tool and includes the correct parameters: 'from_account' as 'ACC-001', 'to_account' as 'ACC-002', 'amount' as 5000, and 'memo' as 'office rent payment'. All parameters are correctly extracted from the conversation. There were no unnecessary tool calls, and no errors were reported in the execution. Therefore, the tool call was fully relevant, efficient, and successful in addressing the user's query.", threshold=3)], run_id='evalrun_15a60026a23442048ebae96960b6ad93', sample=Sample(error=None, finish_reason='', input=[], max_completion_tokens=None, model='', output=[], seed=None, temperature=None, top_p=None, usage=None), status='completed'),
#  OutputItemListResponse(id='3', created_at=1778563239, datasource_item={'query': "I noticed unauthorized charges on account SAV-99999. There's a $2000 ATM withdrawal I didn't make. This is urgent!", 'tool_definitions': [{'type': 'function', 'name': 'get_account_balance', 'description': "Retrieves the current balance for a customer's bank account", 'parameters': {'type': 'object', 'properties': {'account_number': {'type': 'string', 'description': 'The account number to check'}, 'account_type': {'type': 'string', 'description': 'Type of account: checking, savings, or investment'}}}}, {'type': 'function', 'name': 'initiate_wire_transfer', 'description': 'Initiates a wire transfer from one account to another', 'parameters': {'type': 'object', 'properties': {'from_account': {'type': 'string', 'description': 'Source account number'}, 'to_account': {'type': 'string', 'description': 'Destination account number'}, 'amount': {'type': 'number', 'description': 'Amount to transfer in USD'}, 'memo': {'type': 'string', 'description': 'Transfer description or memo'}}}}, {'type': 'function', 'name': 'get_transaction_history', 'description': 'Retrieves recent transactions for a bank account', 'parameters': {'type': 'object', 'properties': {'account_number': {'type': 'string', 'description': 'The account number'}, 'days': {'type': 'integer', 'description': 'Number of days of history to retrieve'}}}}, {'type': 'function', 'name': 'report_suspicious_activity', 'description': 'Reports suspicious or potentially fraudulent activity on an account', 'parameters': {'type': 'object', 'properties': {'account_number': {'type': 'string', 'description': 'The affected account number'}, 'description': {'type': 'string', 'description': 'Description of the suspicious activity'}, 'urgency': {'type': 'string', 'description': 'Urgency level: low, medium, high, critical'}}}}, {'type': 'function', 'name': 'apply_for_loan', 'description': 'Initiates a loan application process', 'parameters': {'type': 'object', 'properties': {'loan_type': {'type': 'string', 'description': 'Type of loan: mortgage, auto, personal'}, 'amount': {'type': 'number', 'description': 'Requested loan amount'}, 'term_months': {'type': 'integer', 'description': 'Loan term in months'}}}}], 'tool_calls': [{'type': 'tool_call', 'tool_call_id': 'call_fraud_1', 'name': 'report_suspicious_activity', 'arguments': {'account_number': 'SAV-99999', 'description': 'Unauthorized ATM withdrawal of $2000', 'urgency': 'high'}}], 'response': None}, datasource_item_id=2, eval_id='eval_e28e53768edc4252bd1820aa9a454190', object='eval.run.output_item', results=[Result(name='tool_call_accuracy', passed=True, score=5.0, sample=None, type='azure_ai_evaluator', metric='tool_call_accuracy', label='pass', reason="Let's think step by step: The user's last query was about unauthorized charges on account SAV-99999, specifically a $2000 ATM withdrawal that they did not make, and they emphasized the urgency of the situation. The relevant tool available for addressing this query is 'report_suspicious_activity', which is designed to report suspicious or potentially fraudulent activity on an account. The tool call made by the agent was 'report_suspicious_activity' with parameters: account_number 'SAV-99999', description 'Unauthorized ATM withdrawal of $2000', and urgency 'high'. These parameters are correctly extracted from the conversation and are relevant to the user's query. There were no unnecessary duplicate tool calls, and the tool call was executed successfully without errors. Therefore, the tool call was fully relevant, efficient, and helped address the user's query without any issues.", threshold=3)], run_id='evalrun_15a60026a23442048ebae96960b6ad93', sample=Sample(error=None, finish_reason='', input=[], max_completion_tokens=None, model='', output=[], seed=None, temperature=None, top_p=None, usage=None), status='completed'),
#  OutputItemListResponse(id='4', created_at=1778563239, datasource_item={'query': 'Show me my last 30 days of transactions for account CHK-55555, and also check the balance.', 'tool_definitions': [{'type': 'function', 'name': 'get_account_balance', 'description': "Retrieves the current balance for a customer's bank account", 'parameters': {'type': 'object', 'properties': {'account_number': {'type': 'string', 'description': 'The account number to check'}, 'account_type': {'type': 'string', 'description': 'Type of account: checking, savings, or investment'}}}}, {'type': 'function', 'name': 'initiate_wire_transfer', 'description': 'Initiates a wire transfer from one account to another', 'parameters': {'type': 'object', 'properties': {'from_account': {'type': 'string', 'description': 'Source account number'}, 'to_account': {'type': 'string', 'description': 'Destination account number'}, 'amount': {'type': 'number', 'description': 'Amount to transfer in USD'}, 'memo': {'type': 'string', 'description': 'Transfer description or memo'}}}}, {'type': 'function', 'name': 'get_transaction_history', 'description': 'Retrieves recent transactions for a bank account', 'parameters': {'type': 'object', 'properties': {'account_number': {'type': 'string', 'description': 'The account number'}, 'days': {'type': 'integer', 'description': 'Number of days of history to retrieve'}}}}, {'type': 'function', 'name': 'report_suspicious_activity', 'description': 'Reports suspicious or potentially fraudulent activity on an account', 'parameters': {'type': 'object', 'properties': {'account_number': {'type': 'string', 'description': 'The affected account number'}, 'description': {'type': 'string', 'description': 'Description of the suspicious activity'}, 'urgency': {'type': 'string', 'description': 'Urgency level: low, medium, high, critical'}}}}, {'type': 'function', 'name': 'apply_for_loan', 'description': 'Initiates a loan application process', 'parameters': {'type': 'object', 'properties': {'loan_type': {'type': 'string', 'description': 'Type of loan: mortgage, auto, personal'}, 'amount': {'type': 'number', 'description': 'Requested loan amount'}, 'term_months': {'type': 'integer', 'description': 'Loan term in months'}}}}], 'tool_calls': [{'type': 'tool_call', 'tool_call_id': 'call_history_1', 'name': 'get_transaction_history', 'arguments': {'account_number': 'CHK-55555', 'days': 30}}, {'type': 'tool_call', 'tool_call_id': 'call_balance_2', 'name': 'get_account_balance', 'arguments': {'account_number': 'CHK-55555', 'account_type': 'checking'}}], 'response': None}, datasource_item_id=3, eval_id='eval_e28e53768edc4252bd1820aa9a454190', object='eval.run.output_item', results=[Result(name='tool_call_accuracy', passed=True, score=5.0, sample=None, type='azure_ai_evaluator', metric='tool_call_accuracy', label='pass', reason="Let's think step by step: The user's last query was to show the last 30 days of transactions for account CHK-55555 and check the balance. The relevant tools available for this query are 'get_transaction_history' for retrieving transaction history and 'get_account_balance' for checking the account balance. The tool calls made were 'get_transaction_history' with parameters {'account_number': 'CHK-55555', 'days': 30} and 'get_account_balance' with parameters {'account_number': 'CHK-55555', 'account_type': 'checking'}. Both tool calls are relevant and correctly address the user's query. The parameters used in both tool calls are correctly extracted from the conversation. There were no unnecessary duplicate tool calls, and no errors occurred during the execution of these tool calls. Therefore, the tool calls were fully relevant, efficient, and optimal for addressing the user's query.", threshold=3)], run_id='evalrun_15a60026a23442048ebae96960b6ad93', sample=Sample(error=None, finish_reason='', input=[], max_completion_tokens=None, model='', output=[], seed=None, temperature=None, top_p=None, usage=None), status='completed'),
#  OutputItemListResponse(id='5', created_at=1778563239, datasource_item={'query': "I'd like to apply for a $25,000 personal loan with a 36-month term.", 'tool_definitions': [{'type': 'function', 'name': 'get_account_balance', 'description': "Retrieves the current balance for a customer's bank account", 'parameters': {'type': 'object', 'properties': {'account_number': {'type': 'string', 'description': 'The account number to check'}, 'account_type': {'type': 'string', 'description': 'Type of account: checking, savings, or investment'}}}}, {'type': 'function', 'name': 'initiate_wire_transfer', 'description': 'Initiates a wire transfer from one account to another', 'parameters': {'type': 'object', 'properties': {'from_account': {'type': 'string', 'description': 'Source account number'}, 'to_account': {'type': 'string', 'description': 'Destination account number'}, 'amount': {'type': 'number', 'description': 'Amount to transfer in USD'}, 'memo': {'type': 'string', 'description': 'Transfer description or memo'}}}}, {'type': 'function', 'name': 'get_transaction_history', 'description': 'Retrieves recent transactions for a bank account', 'parameters': {'type': 'object', 'properties': {'account_number': {'type': 'string', 'description': 'The account number'}, 'days': {'type': 'integer', 'description': 'Number of days of history to retrieve'}}}}, {'type': 'function', 'name': 'report_suspicious_activity', 'description': 'Reports suspicious or potentially fraudulent activity on an account', 'parameters': {'type': 'object', 'properties': {'account_number': {'type': 'string', 'description': 'The affected account number'}, 'description': {'type': 'string', 'description': 'Description of the suspicious activity'}, 'urgency': {'type': 'string', 'description': 'Urgency level: low, medium, high, critical'}}}}, {'type': 'function', 'name': 'apply_for_loan', 'description': 'Initiates a loan application process', 'parameters': {'type': 'object', 'properties': {'loan_type': {'type': 'string', 'description': 'Type of loan: mortgage, auto, personal'}, 'amount': {'type': 'number', 'description': 'Requested loan amount'}, 'term_months': {'type': 'integer', 'description': 'Loan term in months'}}}}], 'tool_calls': [{'type': 'tool_call', 'tool_call_id': 'call_loan_1', 'name': 'apply_for_loan', 'arguments': {'loan_type': 'personal', 'amount': 25000, 'term_months': 36}}], 'response': None}, datasource_item_id=4, eval_id='eval_e28e53768edc4252bd1820aa9a454190', object='eval.run.output_item', results=[Result(name='tool_call_accuracy', passed=True, score=5.0, sample=None, type='azure_ai_evaluator', metric='tool_call_accuracy', label='pass', reason="Let's think step by step: The user's last query was a request to apply for a $25,000 personal loan with a 36-month term. The relevant tool available for this task is 'apply_for_loan', which is defined to initiate a loan application process with parameters for loan type, amount, and term in months. The tool call made by the agent was 'apply_for_loan' with parameters {'loan_type': 'personal', 'amount': 25000, 'term_months': 36}, which are correctly extracted from the user's query. There were no errors in the tool call execution, and no unnecessary or duplicate tool calls were made. Therefore, the tool call was fully relevant, efficient, and executed successfully, addressing the user's query optimally.", threshold=3)], run_id='evalrun_15a60026a23442048ebae96960b6ad93', sample=Sample(error=None, finish_reason='', input=[], max_completion_tokens=None, model='', output=[], seed=None, temperature=None, top_p=None, usage=None), status='completed')]

# %% [markdown]
# ## 9. FSI Compliance Insights

# %%
print("\n" + "=" * 60)
print("💼 FSI COMPLIANCE INSIGHTS - Tool Call Accuracy")
print("=" * 60)

print("\n🎯 Why Tool Call Accuracy Matters in Banking:")
print("-" * 50)
print("   1. SECURITY: Wrong tool could expose sensitive data")
print("   2. COMPLIANCE: Unauthorized actions violate regulations")
print("   3. FINANCIAL: Incorrect transfers = potential losses")
print("   4. AUDIT: All tool calls must be traceable")

print("\n📊 Scenarios Validated:")
print("-" * 50)
print("   ✓ Balance inquiries use read-only tools")
print("   ✓ Wire transfers use proper authorization flow")
print("   ✓ Fraud reports trigger correct escalation")
print("   ✓ Multi-step requests handle all required actions")
print("   ✓ Loan applications route to correct processing")

print("\n🔐 Risk Mitigation:")
print("-" * 50)
print("   • Agents cannot accidentally initiate transfers")
print("   • Fraud alerts reach the right team immediately")
print("   • Parameter extraction is validated")
print("   • All tool selections are auditable")

if eval_run.report_url:
    print(f"\n🔗 View detailed report: {eval_run.report_url}")
# Out:
# ============================================================
# 💼 FSI COMPLIANCE INSIGHTS - Tool Call Accuracy
# ============================================================
#
# 🎯 Why Tool Call Accuracy Matters in Banking:
# --------------------------------------------------
#    1. SECURITY: Wrong tool could expose sensitive data
#    2. COMPLIANCE: Unauthorized actions violate regulations
#    3. FINANCIAL: Incorrect transfers = potential losses
#    4. AUDIT: All tool calls must be traceable
#
# 📊 Scenarios Validated:
# --------------------------------------------------
#    ✓ Balance inquiries use read-only tools
#    ✓ Wire transfers use proper authorization flow
#    ✓ Fraud reports trigger correct escalation
#    ✓ Multi-step requests handle all required actions
#    ✓ Loan applications route to correct processing
#
# 🔐 Risk Mitigation:
# --------------------------------------------------
#    • Agents cannot accidentally initiate transfers
#    • Fraud alerts reach the right team immediately
#    • Parameter extraction is validated
#    • All tool selections are auditable
#
# 🔗 View detailed report: https://ai.azure.com/nextgen/r/_zjmgq_gTsKOGNFN6JSXjw,rg-kd-foundry,,kd-foundry,proj-kd/build/evaluations/eval_e28e53768edc4252bd1820aa9a454190/run/evalrun_15a60026a23442048ebae96960b6ad93

# %% [markdown]
# ## 10. Cleanup

# %%
# # Clean up resources
# try:
#     openai_client.evals.delete(eval_id=eval_object.id)
#     print("🗑️ Evaluation deleted")
# except Exception as e:
#     print(f"⚠️ Could not delete evaluation: {e}")

# print("\n✅ Cleanup completed!")

# %% [markdown]
# ## 🎯 Summary
#
# In this notebook, you learned how to:
#
# ✅ **Define banking tool definitions** with proper schemas
# ✅ **Create test scenarios** covering various banking operations
# ✅ **Use `builtin.tool_call_accuracy`** evaluator
# ✅ **Evaluate tool selection** for correct function calls
# ✅ **Validate parameter extraction** from user queries
#
# ### 🔧 Key APIs Used
#
# | API | Purpose |
# |-----|--------|
# | `DataSourceConfigCustom` | Define schema for evaluation data |
# | `builtin.tool_call_accuracy` | Evaluate correct tool selection |
# | `CreateEvalJSONLRunDataSourceParam` | Pass inline test data |
# | `SourceFileContentContent` | Individual test scenarios |
#
# ### 📊 Data Fields for Tool Call Accuracy
#
# | Field | Description |
# |-------|-------------|
# | `query` | User's input/request |
# | `tool_definitions` | Available tools the agent can use |
# | `tool_calls` | Tools the agent actually called |
# | `response` | Optional - agent's text response |
#
# ### 📚 Next Steps
#
# 1. **Add negative tests** - scenarios where wrong tools are called
# 2. **Test edge cases** - ambiguous queries, missing info
# 3. **Combine with other evaluators** - fluency, safety
# 4. **Integrate into CI/CD** - automated validation
