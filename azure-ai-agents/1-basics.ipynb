# %% [markdown]
# # 🏦 Financial Services Advisor Agent Tutorial 💼
#
# Welcome to our **Financial Services Advisor Agent** tutorial, where you'll use **Microsoft Foundry** SDKs to create a banking and financial assistance AI agent. We'll:
#
# 1. **Initialize** our project using **azure-ai-projects**.
# 2. **Create an Agent** specialized in providing general banking, loan, and investment guidance (with disclaimers!).
# 3. **Manage conversations** about financial services, banking products, and loan inquiries.
# 4. **Showcase logging and tracing** with **OpenTelemetry**.
# 5. **Demonstrate** how to incorporate tools, regulatory disclaimers, and best practices.
#
# ### ⚠️ Important Financial Disclaimer ⚠️
# > **The financial information provided by this notebook is for general educational and demonstration purposes only and is not intended as financial, investment, legal, or tax advice.** Always consult with qualified financial advisors, bankers, or legal professionals before making any financial decisions. Past performance does not guarantee future results. All investments carry risk.
#
#
# ## Let's Get Started
# We'll walk you through each cell with notes. Let's begin!

# %% [markdown]
# ## 🔐 Authentication Setup
#
# Before running the next cell, make sure you're authenticated with Azure CLI. Run this command in your terminal:
#
# ```bash
# az login --use-device-code
# ```
#
# This will provide you with a device code and URL to authenticate in your browser, which is useful for:
# - Remote development environments
# - Systems without a default browser
# - Corporate environments with strict security policies
#
# After successful authentication, you can proceed with the notebook cells below.

# %% [markdown]
# ## 1. Initial Setup
# We'll start by importing needed libraries, loading environment variables, and initializing an **AIProjectClient** so we can do all the agent-related actions. Let's do it! 🎉

# %%
from pathlib import Path  # For working with file paths
import os  # For environment variables
import time  # For sleep function
from dotenv import load_dotenv  # For loading environment variables from .env file
from azure.identity import AzureCliCredential  # For Azure CLI authentication
from azure.ai.projects import AIProjectClient  # Main client for AI Projects
from azure.ai.projects.models import PromptAgentDefinition  # For new agent API

# Get the path to the .env file which is in the parent directory
notebook_path = Path().absolute()  # Get absolute path of current notebook
parent_dir = notebook_path.parent  # Get parent directory
load_dotenv(parent_dir.parent / '.env')  # Load environment variables from .env file

# Get project endpoint
project_endpoint = os.environ.get("AI_FOUNDRY_PROJECT_ENDPOINT")

print(f"🔗 Using Project Endpoint: {project_endpoint}")

# Initialize the AI Project Client using AzureCliCredential (requires 'az login')
try:
    credential = AzureCliCredential()
    
    project_client = AIProjectClient(
        endpoint=project_endpoint,
        credential=credential
    )
    print("✅ Successfully initialized AIProjectClient")
except Exception as e:
    print(f"❌ Error initializing project client: {str(e)}")
    print("💡 Make sure you are logged in via 'az login'")
# Out:
# 🔗 Using Project Endpoint: https://mfbr-ext-eus2-aiml-profx-01.services.ai.azure.com/api/projects/mfbp-ext-eus2-aiml-profx-01
# ✅ Successfully initialized AIProjectClient

# %% [markdown]
# ## 2. Creating our Financial Services Advisor Agent 🏦
#
# We'll create an Agent specialized in general banking and financial guidance. We'll explicitly mention disclaimers in its instructions, so it never forgets regulatory compliance! The instructions also ask the agent to focus on banking products, loan inquiries, and general financial guidance while always encouraging users to seek professional advice.

# %%
def create_financial_advisor_agent():
    """Create a financial services advisor agent with disclaimers and basic instructions using new Foundry API."""
    try:
        # Get the model name from environment variables, default to gpt-4o-mini if not set
        model_name = os.environ.get("AZURE_AI_MODEL_DEPLOYMENT_NAME", "gpt-4o-mini")

        # Create a new agent using the NEW Foundry API with create_version
        # This uses PromptAgentDefinition for defining the agent's behavior
        agent = project_client.agents.create_version(
            agent_name="financial-services-advisor",
            definition=PromptAgentDefinition(
                model=model_name,
                instructions="""
                You are a friendly AI Financial Services Advisor for a retail bank.
                You provide general information about banking products, loans, and financial services, but always:
                1. Include regulatory and financial disclaimers.
                2. Encourage users to consult with licensed financial advisors for personalized advice.
                3. Provide general, non-personalized guidance around banking, loans, savings, and investments.
                4. Clearly remind users you're not a licensed financial advisor and cannot provide investment recommendations.
                5. Follow responsible banking practices and never suggest risky financial behaviors.
                6. Explain concepts like APR, interest rates, credit scores, and loan terms in simple language.
                """
            )
        )
        # Log success and return the created agent
        print(f"🎉 Created financial services advisor agent (name: {agent.name}, version: {agent.version})")
        return agent
    except Exception as e:
        # Handle any errors during agent creation
        print(f"❌ Error creating agent: {str(e)}")
        return None

# Create an instance of our financial services advisor agent
financial_advisor = create_financial_advisor_agent()
# Out:
# 🎉 Created financial services advisor agent (name: financial-services-advisor, version: 1)

# %% [markdown]
# ## 3. Managing Financial Service Conversations 💬
# A conversation (or *thread*) is where we'll store the user's messages and the agent's responses about banking and financial topics. Let's create a new thread dedicated to Financial Services Q&A.

# %%
# Function to create a new conversation for financial services discussions
def start_financial_conversation():
    """Create a new conversation for banking & financial discussions using new Foundry API."""
    try:
        # Get the OpenAI client from project client
        openai_client = project_client.get_openai_client()
        
        # Create a new conversation using the NEW API
        # Conversations replace threads in the new Foundry API
        conversation = openai_client.conversations.create()
        
        # Print success message with the conversation ID for reference
        print(f"📝 Created a new conversation, ID: {conversation.id}")
        
        # Return the created conversation object so we can use it later
        return conversation
    except Exception as e:
        # If conversation creation fails, print error and return None
        print(f"❌ Error creating conversation: {str(e)}")
        return None

# Initialize a new conversation that we'll use for our financial services Q&A
financial_conversation = start_financial_conversation()
# Out:
# 📝 Created a new conversation, ID: conv_35225dea8f67589600fuwe5MNtd3KxNRusIvlLm8rvJV4DuNxt

# %% [markdown]
# ## 4. Asking Banking & Financial Questions 💳
# We'll create messages from the user about typical banking questions. For example, **"What factors affect my mortgage interest rate?"** or **"How do I improve my credit score?"**. We'll let our Financial Advisor Agent respond, always remembering the regulatory disclaimers!

# %%
# Function to chat with our financial services agent using the NEW Foundry API
def chat_with_financial_agent(user_question):
    """Chat with the financial services agent using the new responses API."""
    
    # Check if we have a valid agent
    if not financial_advisor:
        print("❌ No agent available. Please create an agent first.")
        return
    
    try:
        print(f"👤 User: {user_question}")
        print("🔄 Processing with agent...")
        
        # Get the OpenAI client from project client
        openai_client = project_client.get_openai_client()
        
        # Use the NEW responses API with agent_reference
        response = openai_client.responses.create(
            extra_body={
                "agent_reference": {
                    "type": "agent_reference",
                    "name": financial_advisor.name,
                }
            },
            input=user_question
        )
        
        print(f"✅ Agent processing completed!")
        
        # Get the response text
        if response.output_text:
            print(f"🤖 Agent: {response.output_text}")
            return response.output_text
        else:
            print("❌ No response found from agent")
            return None
        
    except Exception as e:
        print(f"❌ Error chatting with agent: {str(e)}")
        import traceback
        print("Full error traceback:")
        traceback.print_exc()
        return None

# Let's test our financial services agent with a simple question
print("🧪 Testing the Financial Services Advisor Agent...")
test_question = "What are the benefits of a savings account?"
chat_with_financial_agent(test_question)
print("=" * 50)
# Out:
# 🧪 Testing the Financial Services Advisor Agent...
# 👤 User: What are the benefits of a savings account?
# 🔄 Processing with agent...
# ✅ Agent processing completed!
# 🤖 Agent: A savings account is a foundational financial tool offered by most banks and credit unions. It allows individuals to safely store money while earning interest over time. Here’s a breakdown of the **key benefits of a savings account**:
#
# ### 1. **Safety and Security**
#    - Funds in a savings account are usually insured by government-backed programs, such as the **FDIC** (Federal Deposit Insurance Corporation) in the U.S. or similar organizations in other countries. For FDIC-insured savings accounts, your money is protected up to $250,000 per depositor, per institution.
#    - Compared to keeping cash at home, a savings account reduces the risk of theft, fire damage, or loss.
#
# ---
#
# ### 2. **Earning Interest**
#    - Your deposits in a savings account typically earn **interest**, which is a small percentage of your balance paid to you periodically. Banks determine this based on their interest rate policy and market conditions.
#    - The interest you earn helps grow your savings over time, albeit at a modest pace compared to some higher-risk investments.
#
# ---
#
# ### 3. **Liquidity**
#    - A savings account offers quick and easy access to your money whenever you need it, making it an excellent tool for short-term financial goals or emergency funds.
#    - While some savings accounts limit the number of withdrawals per month, they generally allow enough flexibility for occasional use of your funds without penalty.
#
# ---
#
# ### 4. **Encourages Saving Discipline**
#    - Having a separate account for savings makes it easier to set aside money for future needs or emergencies. It keeps your savings separate from your checking (spending) account, reducing the temptation to spend it.
#
# ---
#
# ### 5. **Automatic Deposit Options**
#    - Many banks allow you to set up automated transfers from your checking account into your savings account. This helps you save consistently every month, without having to remember to do it manually.
#
# ---
#
# ### 6. **Emergency Fund Accessibility**
#    - A savings account is highly useful for storing **emergency funds**, which can help cover unexpected expenses, such as medical bills, car repairs, or job loss, without relying on debt.
#
# ---
#
# ### 7. **No or Low Account Fees**
#    - Many savings accounts come with **no or low maintenance fees**, particularly if you meet minimum balance requirements. Be sure to review your bank's terms to understand any fees.
#
# ---
#
# ### 8. **Online and Mobile Access**
#    - Modern savings accounts typically come with online and mobile banking features, allowing you to monitor your balance, transfer money, and even deposit checks using your smartphone.
#
# ---
#
# ### 9. **Encourages Goal Setting**
#    - Saving accounts are popular for organizing your finances toward specific goals, like saving for a down payment on a home, a vacation, or holiday shopping. Some banks even let you “bucket” your savings into different named categories for better tracking.
#
# ---
#
# ### 10. **Financial Stability**
#    - A savings account provides a convenient way to set aside money for important milestones, emergencies, or other financial priorities. It contributes to your overall financial stability.
#
# ---
#
# #### **Important Tips When Choosing a Savings Account:**
# 1. Compare **interest rates (APY)** — Some accounts offer higher rates, including high-yield savings accounts.
# 2. Look for accounts with **low or no monthly fees** unless you can waive them.
# 3. Check withdrawal and transaction limits to ensure they align with your needs.
# 4. Use savings for intended purposes, and avoid using it for routine expenses.
#
# ---
#
# #### **Disclaimer:**
# This information is for general educational purposes only and should not be considered personalized financial advice. Always consult with a licensed financial advisor for guidance tailored to your needs. Additionally, before opening a savings account, review all terms, fees, and interest rate disclosures provided by the bank or financial institution.
# ==================================================

# %% [markdown]
# ### Example Financial Services Queries
# Let's do some quick queries now to see the agent's disclaimers and how it handles typical banking and financial questions. We'll ask about **mortgages**, **credit scores**, and **savings strategies**.

# %%
# Test 1: Simple Banking Question (Already completed above)
print("Test 1: Simple Banking Question ✅")
print("-" * 30)

# Test 2: Ask about mortgage rates
print("\nTest 2: Mortgage Advice")
print("-" * 20)
response2 = chat_with_financial_agent("What factors affect my mortgage interest rate and how can I get a better rate?")

print("\n" + "="*60 + "\n")

# Test 3: Ask about credit scores
print("Test 3: Credit Score Guidance")  
print("-" * 20)
response3 = chat_with_financial_agent("How is my credit score calculated and what can I do to improve it?")

print("\n" + "="*60 + "\n")

# Test 4: Ask about savings strategies
print("Test 4: Savings & Investment Basics")
print("-" * 20) 
response4 = chat_with_financial_agent("What's the difference between a savings account, CD, and money market account? Which is best for emergency funds?")

print(f"\n🎉 Completed 4 test conversations with our Financial Services Advisor!")
print(f"All responses received successfully! The agent is working great.")

# Show a summary
successful_tests = sum([1 for r in [True, response2, response3, response4] if r])
print(f"📊 Summary: {successful_tests}/4 tests passed successfully")
# Out:
# Test 1: Simple Banking Question ✅
# ------------------------------
#
# Test 2: Mortgage Advice
# --------------------
# 👤 User: What factors affect my mortgage interest rate and how can I get a better rate?
# 🔄 Processing with agent...
# ✅ Agent processing completed!
# 🤖 Agent: Many factors can affect your mortgage interest rate, both personal to your finances and broader market conditions. Here’s an overview of these factors and some tips for securing a better rate:
#
# ---
#
# ### **Factors That Affect Mortgage Interest Rates**
#
# #### **1. Your Credit Score**
# - **What it is:** Your credit score is a three-digit number (typically ranging from 300–850) that reflects your creditworthiness. It’s based on factors such as your payment history, the amount of debt you owe, and the length of your credit history.
# - **Impact:** A higher credit score typically qualifies you for lower interest rates, as it shows lenders you’re less risky.
# - **What you can do:** Check your credit score and review your credit report for errors. Pay off debts, make on-time payments, and avoid taking on new credit before applying for a mortgage.
#
# #### **2. Loan-to-Value Ratio (LTV)**
# - **What it is:** This is the percentage of the home’s value you’re borrowing. If you make a large down payment, your LTV ratio will be lower.
# - **Impact:** A lower LTV ratio (i.e., a higher down payment) can secure better rates because lenders view you as less of a risk.
# - **What you can do:** Save for a larger down payment to both reduce your LTV and possibly avoid mortgage insurance premiums.
#
# #### **3. Debt-to-Income Ratio (DTI)**
# - **What it is:** Your DTI compares your monthly debt obligations to your gross (pre-tax) income.
# - **Impact:** Lenders prefer borrowers with a lower DTI because they have more room in their budget to make payments. A lower DTI can help you get better rates.
# - **What you can do:** Reduce discretionary debts (like credit card balances) before applying for your mortgage.
#
# #### **4. Market Conditions**
# - **What it is:** Rates fluctuate based on broader economic factors such as inflation, Federal Reserve rates, and demand in the housing market.
# - **Impact:** Rates can vary based on factors outside your control. Fixed-rate mortgages ensure your rate stays stable, while adjustable-rate mortgages (ARMs) may go up or down over time.
# - **What you can do:** Keep an eye on rate trends and consider locking your rate if market conditions are favorable.
#
# #### **5. Loan Type and Term**
# - **What it is:** Different loan types (e.g., conventional, FHA, VA loans) and loan terms (e.g., 15-year vs. 30-year) come with varying rates.
# - **Impact:** Shorter loan terms usually offer lower rates but come with higher monthly payments.
# - **What you can do:** Assess your monthly budget and long-term goals to choose the right loan for your situation.
#
# #### **6. Points and Fees**
# - **What it is:** You can pay "discount points" upfront to lower your interest rate. Each point typically costs 1% of the loan amount.
# - **Impact:** Paying points lowers your rate but increases your upfront costs.
# - **What you can do:** Evaluate whether paying points fits your budget and long-term plans to decide if it’s worth the cost.
#
# ---
#
# ### **How to Improve Your Mortgage Interest Rate**
#
# 1. **Improve Your Credit Score**:
#    - Pay bills on time.
#    - Pay down credit card balances.
#    - Avoid opening new credit accounts before applying for a mortgage.
#
# 2. **Save for a Larger Down Payment**:
#    - Aim for at least 20% down, if possible, to avoid private mortgage insurance (PMI) and qualify for better rates.
#
# 3. **Lower Your Debt**:
#    - Pay off personal loans, auto loans, or other debts to reduce your DTI ratio.
#
# 4. **Shop Around for Lenders**:
#    - Compare offers from multiple lenders, as each lender may offer a slightly different rate and terms.
#
# 5. **Consider Loan Options**:
#    - Look into government-backed loans (FHA, VA, USDA) if you qualify, as they’re designed to offer competitive rates.
#
# 6. **Rate Lock**:
#    - When you find a favorable rate, ask your lender for a "rate lock" to secure it during the application process.
#
# 7. **Choose the Right Timing**:
#    - While timing the market perfectly isn’t always possible, interest rates often move lower during times of reduced economic activity.
#
# ---
#
# ### **Regulatory and Disclaimer Note**
# - The information provided here is general in nature and may not apply to your specific financial situation.
# - I recommend consulting with a **licensed mortgage advisor or loan officer** who can assess your unique circumstances and help you choose the best loan option.
# - Always read the terms, fees, and conditions of any mortgage agreement carefully and ask questions if anything is unclear.
#
# Let me know if you have further questions about mortgages or any other financial topics! I'm happy to help.
#
# ============================================================
#
# Test 3: Credit Score Guidance
# --------------------
# 👤 User: How is my credit score calculated and what can I do to improve it?
# 🔄 Processing with agent...
# ✅ Agent processing completed!
# 🤖 Agent: Your credit score is essentially a three-digit number designed to give an idea of how trustworthy you are as a borrower. Most commonly, it's calculated using a formula like the one from FICO® or VantageScore®. Here's an overview of how your credit score is typically calculated:
#
# ---
#
# ### Components of a Credit Score:
#
# 1. **Payment History (35%)**
#    This is the most important factor. Lenders want to know if you consistently pay your bills on time. Late payments, missed payments, and delinquencies negatively affect your score.
#
# 2. **Amounts Owed (30%)**
#    This measures how much of your available credit you're using, also known as your **credit utilization rate**. A lower utilization rate (experts often recommend keeping it below 30%) is viewed more favorably.
#
# 3. **Length of Credit History (15%)**
#    A longer credit history demonstrates to lenders that you have more experience managing credit.
#
# 4. **Credit Mix (10%)**
#    Having a combination of credit types (e.g., credit cards, auto loans, mortgages) shows that you can handle different types of debt responsibly.
#
# 5. **New Credit (10%)**
#    Opening several new credit accounts in a short time may negatively affect your score, as it can indicate financial instability. Each time a lender checks your credit for a new account (a **hard inquiry**), that inquiry is noted and may slightly lower your score temporarily.
#
# ---
#
# ### How to Improve Your Credit Score:
#
# 1. **Pay Bills on Time**
#    Set reminders or automate payments to ensure you never miss a due date. Even a single missed payment can harm your score.
#
# 2. **Reduce Credit Card Balances**
#    Aim to pay down existing credit card debt and minimize how much of your credit limit you're using. Reducing your credit utilization rate is one of the quickest ways to improve your score.
#
# 3. **Keep Old Accounts Open**
#    Closing old credit accounts shortens your credit history, which can lower your score. If you don't need to close an old account, consider keeping it open to show a long credit history.
#
# 4. **Limit New Credit Applications**
#    Avoid applying for too many credit accounts in a short period. Only apply for credit when you actually need it.
#
# 5. **Check for Errors on Your Credit Report**
#    Errors on your credit report can drag your score down. You’re entitled to a free credit report once a year from each of the three major credit bureaus (Equifax, Experian, and TransUnion) at **AnnualCreditReport.com**. Review your report for inaccuracies and dispute any errors you find.
#
# 6. **Consider a Secured Credit Card**
#    If you're trying to build or rebuild credit, a secured credit card (where you put down a refundable deposit as collateral) can help demonstrate responsible credit use.
#
# 7. **Be Patient**
#    Improving a credit score takes time and consistency. Avoid quick fixes or risky shortcuts, as they may backfire in the long term.
#
# ---
#
# ### Why Does a Good Credit Score Matter?
#
# A higher credit score can help you qualify for loans, credit cards, and lower interest rates, which means you'll pay less in interest over time. It also matters for renting apartments, getting insurance, and sometimes even when applying for jobs.
#
# ---
#
# ### Regulatory Disclaimer:
#
# Remember, I’m here to provide general information, but I’m not a licensed financial advisor or credit specialist. Credit building strategies vary by individual circumstances, so consult a certified financial or credit counselor for personalized advice.
#
# Would you like any additional information about credit, loans, or banking services? 😊
#
# ============================================================
#
# Test 4: Savings & Investment Basics
# --------------------
# 👤 User: What's the difference between a savings account, CD, and money market account? Which is best for emergency funds?
# 🔄 Processing with agent...
# ✅ Agent processing completed!
# 🤖 Agent: Great question! Savings accounts, certificates of deposit (CDs), and money market accounts are all banking products designed to help you save money, but they work differently. Here's a comparison and guidance on which might be best for emergency funds:
#
# ---
#
# ### **1. Savings Account**
# - **Purpose**: A basic account for storing money that you might need quick access to.
# - **Interest Rate**: Typically lower, but rates can vary between banks, especially with online savings accounts.
# - **Liquidity**: Very liquid—you can withdraw money anytime without penalty, though federal regulations (Regulation D) may limit certain types of withdrawals to six per month in some cases.
# - **Other Notes**: Often used for short-term or emergency savings.
#
# ---
#
# ### **2. Certificate of Deposit (CD)**
# - **Purpose**: A fixed-term investment where your money is locked in for a certain period (e.g., six months, one year, five years) in exchange for higher interest rates.
# - **Interest Rate**: Usually higher than a savings account, but interest varies by term length—longer terms typically offer higher rates.
# - **Liquidity**: Low—you can't withdraw money without paying a penalty if you access it before the term ends.
# - **Other Notes**: Best for money you won't need for the duration of the term but want to grow safely.
#
# ---
#
# ### **3. Money Market Account (MMA)**
# - **Purpose**: A hybrid account that combines features of a savings and checking account. MMAs may offer higher interest rates than standard savings accounts.
# - **Interest Rate**: Higher than regular savings accounts but might require large deposits to earn the maximum rate.
# - **Liquidity**: Accessible, but subject to withdrawal limits like savings accounts. Some MMAs may allow you to write checks or use a debit card.
# - **Other Notes**: Typically good for higher balances.
#
# ---
#
# ### **Which is Best for Emergency Funds?**
# For emergency funds, **liquidity** is key. You want to ensure quick and easy access to your money without penalties because emergencies are unpredictable. Here's the breakdown:
# - **Savings Account**: **Best option.** Easy to access, no risks of losing principal, and no early withdrawal penalties.
# - **Certificate of Deposit (CD)**: **Not ideal unless it's a no-penalty CD.** Your money is tied up for the term, and there could be fees for early withdrawal.
# - **Money Market Account (MMA)**: **Good option.** It’s slightly less accessible than a simple savings account but offers higher interest rates if you meet balance requirements.
#
# ---
#
# ### Things to Remember:
# 1. **Keep funds liquid**: For emergencies, prioritize access over interest rate.
# 2. **Consider FDIC Insurance**: Ensure any account you use is insured by the FDIC (or NCUA for credit unions) for up to $250,000 per depositor, per institution.
# 3. **Combine approaches**: Some people use a combination—e.g., a savings account for near-term emergencies and a portion of their emergency fund in a no-penalty CD or MMA for slightly higher interest.
#
# ---
#
# **Disclaimer**: I’m not a licensed financial advisor, so this is general guidance. For personalized advice tailored to your financial needs, please consult with a licensed financial expert or banker.
#
# 🎉 Completed 4 test conversations with our Financial Services Advisor!
# All responses received successfully! The agent is working great.
# 📊 Summary: 4/4 tests passed successfully

# %% [markdown]
# ## 5. Final Test: Complex Financial Question 🧹

# %%
# Advanced: Multi-turn conversation with context
def chat_with_context(user_question, conversation_id=None):
    """Chat using an existing conversation for multi-turn context."""
    
    if not financial_advisor:
        print("❌ No agent available.")
        return None
    
    try:
        print(f"👤 User: {user_question}")
        
        # Get the OpenAI client
        openai_client = project_client.get_openai_client()
        
        # Use responses API with conversation context
        response = openai_client.responses.create(
            conversation=conversation_id,
            extra_body={
                "agent_reference": {
                    "type": "agent_reference",
                    "name": financial_advisor.name,
                }
            },
            input=user_question
        )
        
        if response.output_text:
            print(f"🤖 Agent: {response.output_text}")
            return response.output_text
        else:
            print("❌ No response from agent")
            return None
            
    except Exception as e:
        print(f"❌ Error: {str(e)}")
        return None

# Let's create one more test conversation to demonstrate the agent's capabilities
print("🔍 Final Test: Complex Financial Scenario")
print("=" * 40)

final_response = chat_with_financial_agent(
    "I'm a 30-year-old first-time homebuyer with $50,000 saved for a down payment. I have a credit score of 720 and an annual income of $85,000. I'm looking at homes around $350,000. Should I consider a 15-year or 30-year mortgage, and what other costs should I budget for when buying a home?"
)

if final_response:
    print(f"\n✅ Final test successful!")
    print(f"\n🎯 Our Financial Services Advisor Agent is fully functional and ready to help customers with banking inquiries!")
else:
    print(f"\n❌ Final test failed.")
# Out:
# 🔍 Final Test: Complex Financial Scenario
# ========================================
# 👤 User: I'm a 30-year-old first-time homebuyer with $50,000 saved for a down payment. I have a credit score of 720 and an annual income of $85,000. I'm looking at homes around $350,000. Should I consider a 15-year or 30-year mortgage, and what other costs should I budget for when buying a home?
# 🔄 Processing with agent...
# ✅ Agent processing completed!
# 🤖 Agent: Congratulations on preparing to buy your first home! Becoming a homeowner is an exciting milestone, but it does come with financial considerations. Let's explore your questions step by step.
#
# ### 1. **15-Year vs. 30-Year Mortgage: Which to Choose?**
#
# The decision between a **15-year mortgage** and a **30-year mortgage** depends on your financial goals, monthly cash flow, and comfort level with payment size. Here's an overview:
#
# - **15-Year Mortgage:**
#   - **Pros:**
#     - Shorter loan term, so you’ll pay off your home faster.
#     - Lower total interest paid over the life of the loan.
#     - Typically, lower interest rates than 30-year mortgages.
#   - **Cons:**
#     - Higher monthly payments since the repayment period is shorter.
#     - Less flexibility if financial situations change (e.g., unexpected expenses).
#
# - **30-Year Mortgage:**
#   - **Pros:**
#     - Lower monthly payments, giving you more flexibility in your budget.
#     - Easier to qualify for due to lower payment obligations.
#     - Allows you to allocate more money toward savings, retirement, or other investments.
#   - **Cons:**
#     - Higher total interest paid over the life of the loan.
#     - Typically higher interest rates compared to a 15-year mortgage.
#
# ### Example:
# Assuming you borrow $300,000 (purchase price of $350,000 minus $50,000 down payment):
#
# - For a **30-year fixed-rate mortgage** at an interest rate of 6.5%:
#   - Approximate monthly principal and interest: **$1,896**
#   - Total interest paid over 30 years: **$382,635**
#
# - For a **15-year fixed-rate mortgage** at an interest rate of 5.75%:
#   - Approximate monthly principal and interest: **$2,497**
#   - Total interest paid over 15 years: **$149,551**
#
# These calculations exclude taxes, homeowner’s insurance, and other costs. The 15-year saves you significant interest in the long run, but the monthly payment is over $600 higher than the 30-year option.
#
# **Tip:** If you can comfortably afford higher payments while still saving for retirement, staying out of debt, and building emergency savings, the 15-year mortgage may make sense. Otherwise, the 30-year option provides financial flexibility.
#
# ---
#
# ### 2. **Other Costs to Budget For When Buying a Home**
#
# In addition to your down payment, you’ll need to budget for the following expenses:
#
# #### Upfront Costs:
# 1. **Closing Costs** (2%–5% of home price):
#    - These include lender fees, title insurance, appraisal, home inspection, and more.
#    - For a $350,000 home, estimate around $7,000–$17,500 in closing costs.
#
# 2. **Home Inspection**:
#    - Typically costs $300–$600, but it’s well worth it to discover any potential issues before buying.
#
# 3. **Prepaid Items**:
#    - Lenders often require prepayment of property taxes and homeowner’s insurance for the next several months. This can amount to a few thousand dollars.
#
# 4. **Private Mortgage Insurance (PMI)**:
#    - If your down payment is less than 20%, most lenders will require you to pay PMI, which typically costs 0.3%–1.5% of the loan amount annually.
#
# #### Ongoing Costs:
# 1. **Mortgage Payment**:
#    - Includes principal, interest, taxes, and insurance (commonly referred to as PITI).
#    - Taxes and insurance vary by location; check with local professionals for estimates.
#
# 2. **Homeowner’s Insurance**:
#    - Protects you in case of damage to your home. Costs vary depending on the home, location, and coverage needs.
#
# 3. **Property Taxes**:
#    - Based on the assessed value of your home and local tax rates. Your lender may include this in your monthly payment.
#
# 4. **Home Maintenance and Repairs**:
#    - Experts recommend budgeting 1%–2% of your home’s purchase price annually for maintenance and repairs.
#    - For a $350,000 home, this is $3,500–$7,000 per year.
#
# 5. **HOA Fees (if applicable)**:
#    - Check whether your new home is in a community that requires homeowners’ association fees.
#
# ---
#
# ### 3. **General Tips for First-Time Homebuyers**
# - **Emergency Fund:** Ensure you still have an emergency fund after your down payment and closing costs. Three to six months of living expenses is ideal.
# - **Pre-Approval:** Get pre-approved for a mortgage before house hunting to understand how much you can borrow and show sellers you're a serious buyer.
# - **Avoid Overstretching:** Just because you're approved for a certain loan amount doesn’t mean you should borrow that much. Choose a price range you can comfortably afford.
# - **Consult Professionals:** Work with a real estate agent, lender, and licensed financial or tax advisor to ensure you understand all aspects of the purchase.
#
# ---
#
# ### Final Disclaimer
# I am not a licensed financial advisor or loan officer. The information provided is for general educational purposes only and should not be considered financial advice. For personalized guidance, consult a licensed mortgage professional and/or financial advisor who can help assess your specific situation.
#
# Good luck on your home-buying journey! Let me know if you’d like clarification or help with other details.
#
# ✅ Final test successful!
#
# 🎯 Our Financial Services Advisor Agent is fully functional and ready to help customers with banking inquiries!

# %% [markdown]
# ## 5. Cleanup 🧹
# If you'd like to remove your agent from the service once finished, you can do so below. (In production, you might keep your agent around for stateful experiences!)

# %%
# Clean up resources using new Foundry API
project_client.agents.delete_version(agent_name=financial_advisor.name, agent_version=financial_advisor.version)
print("🗑️ Deleted agent")
print("✅ Cleanup completed!")
# Out:
# 🗑️ Deleted agent
# ✅ Cleanup completed!

# %% [markdown]
# # Congratulations! 🏆
# You've successfully built a **Financial Services Advisor** that can:
# 1. **Respond** to basic banking, loan, and financial questions.
# 2. **Use disclaimers** to ensure regulatory compliance and encourage professional consultation.
# 3. **Provide** general banking product and savings information.
# 4. **Use** the synergy of **Microsoft Foundry** modules to power the conversation.
#
# ## Next Steps
# - Explore adding more advanced tools (like **FileSearchTool** or **CodeInterpreterTool**) to analyze loan documents or financial data.
# - Evaluate your AI's performance with **azure-ai-evaluation**!
# - Add **OpenTelemetry** or Azure Monitor for deeper insights.
# - Incorporate **function calling** if you want to handle things like loan calculations or account lookups.
#
# Happy banking automation! 💰

# %% [markdown]
# ## 🎯 Summary
#
# Congratulations! You've successfully:
#
# ✅ **Connected to Microsoft Foundry** - Established secure connection using authentication
# ✅ **Created an AI Agent** - Built a specialized Financial Services Advisor
# ✅ **Implemented Chat Functionality** - Created functions to interact with the agent
# ✅ **Tested Multiple Scenarios** - Verified the agent works for various banking questions
#
# ### Key Concepts Learned
#
# 1. **Azure AI Agent Service** - A managed service for building intelligent AI assistants
# 2. **Threads** - Conversation sessions that maintain context between messages
# 3. **Runs** - Agent processing operations that handle user queries and generate responses
# 4. **Messages** - Individual communications between users and agents
#
# ### 🔧 Key Takeaways
#
# - The **`create_thread_and_process_run()`** method is the simplest way to interact with agents
# - Agents automatically maintain conversation context within threads
# - The agent provides responsible AI disclaimers for financial advice
# - Error handling is crucial when working with AI services
