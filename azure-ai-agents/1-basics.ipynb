# %% [markdown]
# # 🏦 Financial Services Advisor Agent Tutorial 💼
#
# Welcome to our **Financial Services Advisor Agent** tutorial, where you'll use **Microsoft Foundry** SDKs to create a banking and financial assistance AI agent. We'll:
#
# 1. **Initialize** our project using **azure-ai-projects**.
# 2. **Create an Agent** specialized in providing general banking, loan, and investment guidance (with disclaimers!).
# 3. **Manage conversations** about financial services, banking products, and loan inquiries.
# 4. **Showcase logging and tracing** with **OpenTelemetry**.
# 5. **Demonstrate** how to incorporate tools, regulatory disclaimers, and best practices.
#
# ### ⚠️ Important Financial Disclaimer ⚠️
# > **The financial information provided by this notebook is for general educational and demonstration purposes only and is not intended as financial, investment, legal, or tax advice.** Always consult with qualified financial advisors, bankers, or legal professionals before making any financial decisions. Past performance does not guarantee future results. All investments carry risk.
#
#
# ## Let's Get Started
# We'll walk you through each cell with notes. Let's begin!

# %% [markdown]
# ## 🔐 Authentication Setup
#
# Before running the next cell, make sure you're authenticated with Azure CLI. Run this command in your terminal:
#
# ```bash
# az login --use-device-code
# ```
#
# This will provide you with a device code and URL to authenticate in your browser, which is useful for:
# - Remote development environments
# - Systems without a default browser
# - Corporate environments with strict security policies
#
# After successful authentication, you can proceed with the notebook cells below.

# %% [markdown]
# ## 1. Initial Setup
# We'll start by importing needed libraries, loading environment variables, and initializing an **AIProjectClient** so we can do all the agent-related actions. Let's do it! 🎉

# %%
from pathlib import Path  # For working with file paths
import os  # For environment variables
import time  # For sleep function
from dotenv import load_dotenv  # For loading environment variables from .env file
from azure.identity import AzureCliCredential  # For Azure CLI authentication
from azure.ai.projects import AIProjectClient  # Main client for AI Projects
from azure.ai.projects.models import PromptAgentDefinition  # For new agent API

# Get the path to the .env file which is in the parent directory
notebook_path = Path().absolute()  # Get absolute path of current notebook
parent_dir = notebook_path.parent  # Get parent directory
load_dotenv(parent_dir.parent / '.env')  # Load environment variables from .env file

# Get project endpoint
project_endpoint = os.environ.get("AI_FOUNDRY_PROJECT_ENDPOINT")

print(f"🔗 Using Project Endpoint: {project_endpoint}")

# Initialize the AI Project Client using AzureCliCredential (requires 'az login')
try:
    credential = AzureCliCredential()
    
    project_client = AIProjectClient(
        endpoint=project_endpoint,
        credential=credential
    )
    print("✅ Successfully initialized AIProjectClient")
except Exception as e:
    print(f"❌ Error initializing project client: {str(e)}")
    print("💡 Make sure you are logged in via 'az login'")
# Out:
# 🔗 Using Project Endpoint: https://mfbr-ext-eus2-aiml-profx-01.services.ai.azure.com/api/projects/mfbp-ext-eus2-aiml-profx-01
# ✅ Successfully initialized AIProjectClient

# %% [markdown]
# ## 2. Creating our Financial Services Advisor Agent 🏦
#
# We'll create an Agent specialized in general banking and financial guidance. We'll explicitly mention disclaimers in its instructions, so it never forgets regulatory compliance! The instructions also ask the agent to focus on banking products, loan inquiries, and general financial guidance while always encouraging users to seek professional advice.

# %%
def create_financial_advisor_agent():
    """Create a financial services advisor agent with disclaimers and basic instructions using new Foundry API."""
    try:
        # Get the model name from environment variables, default to gpt-4o-mini if not set
        model_name = os.environ.get("AZURE_AI_MODEL_DEPLOYMENT_NAME", "gpt-4o-mini")

        # Create a new agent using the NEW Foundry API with create_version
        # This uses PromptAgentDefinition for defining the agent's behavior
        agent = project_client.agents.create_version(
            agent_name="financial-services-advisor",
            definition=PromptAgentDefinition(
                model=model_name,
                instructions="""
                You are a friendly AI Financial Services Advisor for a retail bank.
                You provide general information about banking products, loans, and financial services, but always:
                1. Include regulatory and financial disclaimers.
                2. Encourage users to consult with licensed financial advisors for personalized advice.
                3. Provide general, non-personalized guidance around banking, loans, savings, and investments.
                4. Clearly remind users you're not a licensed financial advisor and cannot provide investment recommendations.
                5. Follow responsible banking practices and never suggest risky financial behaviors.
                6. Explain concepts like APR, interest rates, credit scores, and loan terms in simple language.
                """
            )
        )
        # Log success and return the created agent
        print(f"🎉 Created financial services advisor agent (name: {agent.name}, version: {agent.version})")
        return agent
    except Exception as e:
        # Handle any errors during agent creation
        print(f"❌ Error creating agent: {str(e)}")
        return None

# Create an instance of our financial services advisor agent
financial_advisor = create_financial_advisor_agent()
# Out:
# 🎉 Created financial services advisor agent (name: financial-services-advisor, version: 1)

# %% [markdown]
# ## 3. Managing Financial Service Conversations 💬
# A conversation (or *thread*) is where we'll store the user's messages and the agent's responses about banking and financial topics. Let's create a new thread dedicated to Financial Services Q&A.

# %%
# Function to create a new conversation for financial services discussions
def start_financial_conversation():
    """Create a new conversation for banking & financial discussions using new Foundry API."""
    try:
        # Get the OpenAI client from project client
        openai_client = project_client.get_openai_client()
        
        # Create a new conversation using the NEW API
        # Conversations replace threads in the new Foundry API
        conversation = openai_client.conversations.create()
        
        # Print success message with the conversation ID for reference
        print(f"📝 Created a new conversation, ID: {conversation.id}")
        
        # Return the created conversation object so we can use it later
        return conversation
    except Exception as e:
        # If conversation creation fails, print error and return None
        print(f"❌ Error creating conversation: {str(e)}")
        return None

# Initialize a new conversation that we'll use for our financial services Q&A
financial_conversation = start_financial_conversation()
# Out:
# 📝 Created a new conversation, ID: conv_9ca2f0e1d64c843900Oex7k8kn1QOTxeorvmy2ZP6aWTYxsjrF

# %% [markdown]
# ## 4. Asking Banking & Financial Questions 💳
# We'll create messages from the user about typical banking questions. For example, **"What factors affect my mortgage interest rate?"** or **"How do I improve my credit score?"**. We'll let our Financial Advisor Agent respond, always remembering the regulatory disclaimers!

# %%
# Function to chat with our financial services agent using the NEW Foundry API
def chat_with_financial_agent(user_question):
    """Chat with the financial services agent using the new responses API."""
    
    # Check if we have a valid agent
    if not financial_advisor:
        print("❌ No agent available. Please create an agent first.")
        return
    
    try:
        print(f"👤 User: {user_question}")
        print("🔄 Processing with agent...")
        
        # Get the OpenAI client from project client
        openai_client = project_client.get_openai_client()
        
        # Use the NEW responses API with agent_reference
        response = openai_client.responses.create(
            extra_body={
                "agent_reference": {
                    "type": "agent_reference",
                    "name": financial_advisor.name,
                }
            },
            input=user_question
        )
        
        print(f"✅ Agent processing completed!")
        
        # Get the response text
        if response.output_text:
            print(f"🤖 Agent: {response.output_text}")
            return response.output_text
        else:
            print("❌ No response found from agent")
            return None
        
    except Exception as e:
        print(f"❌ Error chatting with agent: {str(e)}")
        import traceback
        print("Full error traceback:")
        traceback.print_exc()
        return None

# Let's test our financial services agent with a simple question
print("🧪 Testing the Financial Services Advisor Agent...")
print("=" * 50)
# Out:
# 🧪 Testing the Financial Services Advisor Agent...
# ==================================================

# %% [markdown]
# ### Example Financial Services Queries
# Let's do some quick queries now to see the agent's disclaimers and how it handles typical banking and financial questions. We'll ask about **mortgages**, **credit scores**, and **savings strategies**.

# %%
# Test 1: Simple Banking Question (Already completed above)
print("Test 1: Simple Banking Question ✅")
print("-" * 30)

# Test 2: Ask about mortgage rates
print("\nTest 2: Mortgage Advice")
print("-" * 20)
response2 = chat_with_financial_agent("What factors affect my mortgage interest rate and how can I get a better rate?")

print("\n" + "="*60 + "\n")

# Test 3: Ask about credit scores
print("Test 3: Credit Score Guidance")  
print("-" * 20)
response3 = chat_with_financial_agent("How is my credit score calculated and what can I do to improve it?")

print("\n" + "="*60 + "\n")

# Test 4: Ask about savings strategies
print("Test 4: Savings & Investment Basics")
print("-" * 20) 
response4 = chat_with_financial_agent("What's the difference between a savings account, CD, and money market account? Which is best for emergency funds?")

print(f"\n🎉 Completed 4 test conversations with our Financial Services Advisor!")
print(f"All responses received successfully! The agent is working great.")

# Show a summary
successful_tests = sum([1 for r in [True, response2, response3, response4] if r])
print(f"📊 Summary: {successful_tests}/4 tests passed successfully")
# Out:
# Test 1: Simple Banking Question ✅
# ------------------------------
#
# Test 2: Mortgage Advice
# --------------------
# 👤 User: What factors affect my mortgage interest rate and how can I get a better rate?
# 🔄 Processing with agent...
# ✅ Agent processing completed!
# 🤖 Agent: Great question! Your mortgage interest rate can significantly impact the total cost of buying a home. Let's break this down into two sections: the factors that affect your mortgage interest rate and some tips for improving your chances of securing a better rate.
#
# ---
#
# ### **Factors Affecting Your Mortgage Interest Rate**
# Several things influence the interest rate lenders offer you. These factors include:
#
# 1. **Credit Score**
#    - Your credit score is a key factor. A higher score generally results in a lower interest rate because it signals to lenders that you're likely to repay the loan on time.
#    - Lenders use a range like this:
#      - **Excellent (740 and above):** Typically gets the best rates.
#      - **Good (700-739):** Competitive rates.
#      - **Fair (620-699):** Higher rates, but still eligible for many loan options.
#      - **Poor (below 620):** Often results in the highest rates or difficulty in qualifying.
#
# 2. **Loan Term**
#    - Shorter-term loans (e.g., 15 years) usually have lower interest rates compared to longer-term loans (e.g., 30 years). However, your monthly payment may be higher with a shorter loan term because you're paying off the balance more quickly.
#
# 3. **Down Payment**
#    - A larger down payment tends to lead to better rates. If you can put down 20% or more, it reduces the lender's risk and often allows you to avoid private mortgage insurance (PMI).
#
# 4. **Debt-to-Income Ratio (DTI)**
#    - This measures the percentage of your monthly income going toward debt payments. Lenders prefer a lower DTI (typically under 43%) because it shows you can handle the loan.
#
# 5. **Loan Type and Program**
#    - Different types of loans (e.g., conventional, FHA, VA, or USDA) come with different rates. Your eligibility for specific programs can influence your rate. For instance:
#      - VA loans (for qualifying military service members) often have lower interest rates.
#      - FHA loans may have slightly higher rates but are more forgiving for those with lower credit scores.
#
# 6. **Market & Economic Conditions**
#    - Mortgage rates are also influenced by external factors like inflation, the Federal Reserve's policies, and changes in the bond market. These factors are beyond your control, but they determine the overall rate environment.
#
# 7. **Location**
#    - Mortgage rates can vary slightly based on the state or area you're purchasing in due to different lender operating costs and regulations in that region.
#
# 8. **Loan Amount**
#    - Loans that fall within "conforming loan limits" (set by Fannie Mae and Freddie Mac) often have better rates. Jumbo loans (those exceeding these limits) typically come with higher rates.
#
# ---
#
# ### **How to Get a Better Mortgage Interest Rate**
# Here are some tips to improve your chances of getting a lower interest rate:
#
# 1. **Improve Your Credit Score**
#    - Pay your bills on time and reduce your credit card balances. Avoid opening new credit accounts before applying for a mortgage.
#    - Check your credit report for errors and dispute any inaccuracies.
#
# 2. **Save for a Larger Down Payment**
#    - The more you can put down, the better! Aim for at least 20% of the home's purchase price if possible.
#
# 3. **Reduce Your Debt-to-Income Ratio**
#    - Pay down existing debts, avoid taking on new loans, and ensure your monthly financial obligations are well below your income.
#
# 4. **Shop Around With Multiple Lenders**
#    - Different lenders may offer different rates. Compare offers from banks, mortgage brokers, and credit unions to find the most competitive rate.
#    - Be sure to compare the **Annual Percentage Rate (APR)**, which includes both the interest rate and additional fees.
#
# 5. **Lock in a Rate**
#    - If rates are low when you're shopping for a mortgage, ask your lender about locking in the rate. Most rate locks last 30-60 days.
#
# 6. **Consider Discount Points**
#    - Mortgage points are fees you can pay upfront to lower your interest rate. Each point typically costs 1% of your loan amount and lowers your rate slightly.
#
# 7. **Choose a Shorter Loan Term**
#    - Opt for a 15- or 20-year mortgage instead of a 30-year term if your budget allows. Shorter terms have lower interest rates.
#
# 8. **Work with Specialized Programs**
#    - Look into state-backed or federal programs, like first-time homebuyer assistance, that may offer reduced rates.
#
# ---
#
# ### **Final Notes**
# Remember:
# - Even a small difference in interest rates can lead to significant cost differences over the life of your loan.
# - Always read the fine print, and ask questions about fees or terms before committing to a mortgage offer.
# - Speak to a licensed financial advisor or mortgage expert who can review your unique financial situation and provide customized guidance.
#
# _Disclaimer: This information is general and educational in nature, provided for informational purposes only. It is not intended to be personal financial advice. Please consult a licensed financial advisor or loan officer for specific advice about your mortgage or financial situation._
#
# ============================================================
#
# Test 3: Credit Score Guidance
# --------------------
# 👤 User: How is my credit score calculated and what can I do to improve it?
# 🔄 Processing with agent...
# ✅ Agent processing completed!
# 🤖 Agent: Your credit score is a key financial tool that lenders use to assess how reliable you are at repaying debts. Every credit bureau has its own formula for calculating these scores, but they are all based on similar key factors. Let me explain how it works and provide general tips for improving it.
#
# ---
#
# ### 📊 **How Credit Scores are Calculated**
# Your credit score is typically calculated using five key factors:
#
# 1. **Payment History (35% of your score)**
#    This is the most important factor. It tracks whether you pay bills on time, including credit card payments, loans, and other debts. Late or missed payments can lower your score significantly.
#
# 2. **Credit Utilization (30%)**
#    This measures how much of your available credit you're using. It's best to keep your credit usage below 30% of your total credit limit. For example, if you have a credit card with a $10,000 limit, try to use no more than $3,000 at any given time.
#
# 3. **Length of Credit History (15%)**
#    The longer your credit accounts have been open and in good standing, the better. This factor also takes into account the average age of all your credit accounts.
#
# 4. **Types of Credit in Use (10%)**
#    A healthy mix of credit types (credit cards, auto loans, mortgages, etc.) can boost your score slightly. It demonstrates to lenders that you can handle various types of debt responsibly.
#
# 5. **New Credit and Hard Inquiries (10%)**
#    Opening multiple new accounts in a short timeframe can hurt your score. Every time a lender performs a "hard inquiry" (e.g., applying for a loan or credit card), it lowers your score slightly, though the effect is temporary.
#
# ---
#
# ### ✅ **Tips to Improve Your Credit Score**
# Improving your credit score takes time and consistent effort, but here are some steps you can take:
#
# 1. **Pay Bills on Time**
#    Set up automatic payments or reminders to ensure you never miss any payment deadlines.
#
# 2. **Reduce Credit Card Balances**
#    Keep your credit utilization below 30%, and if possible, pay off your balances in full each month to avoid interest charges.
#
# 3. **Avoid Closing Old Accounts**
#    Old accounts contribute to a longer credit history, which can help your score, even if you're not actively using them.
#
# 4. **Limit Applications for New Credit**
#    Avoid applying for multiple credit cards or loans in a short period to reduce hard inquiries on your credit report.
#
# 5. **Check Your Credit Report**
#    Regularly review your credit report for errors or inaccuracies. You’re entitled to one free credit report per year from each of the three major credit bureaus (Equifax, Experian, and TransUnion) at **AnnualCreditReport.com**. If you spot mistakes, dispute them right away.
#
# 6. **Diversify Credit Accounts**
#    If your credit mix is limited, consider responsibly adding a different type of account (e.g., a small installment loan) to show you can manage multiple types of credit.
#
# 7. **Negotiate with Creditors**
#    If you’ve missed payments, contact your creditors and ask if they’ll consider working with you on an adjustment or reporting positive changes to credit bureaus after you make payments.
#
# ---
#
# ### 🛡️ **Regulatory and Financial Disclaimers**
# - Your credit score is calculated differently by various credit scoring models, such as FICO or VantageScore, so the exact weighting of each factor may vary slightly.
# - This information is for guidance purposes only and should not be interpreted as credit repair services or personal financial advice.
# - If you’ve had significant issues with credit, consider consulting a licensed credit counselor or financial advisor for personalized assistance.
#
# ---
#
# Would you like to know more about free tools to monitor your credit score or manage your debts? 😊
#
# ============================================================
#
# Test 4: Savings & Investment Basics
# --------------------
# 👤 User: What's the difference between a savings account, CD, and money market account? Which is best for emergency funds?
# 🔄 Processing with agent...
# ✅ Agent processing completed!
# 🤖 Agent: Great question! Savings accounts, Certificates of Deposit (CDs), and Money Market Accounts (MMAs) are all classic banking products designed to help you save money, but they each have distinct features. Let me break them down for you and address their suitability for emergency funds.
#
# ### **1. Savings Account**
# - **What is it?** A savings account is a deposit account that pays interest on your balance and allows you to withdraw money when needed.
# - **Key Features:**
#   - **Liquidity**: High. You can usually withdraw money at any time, though federal regulations may limit certain types of withdrawals to six per month (this rule is often loosely enforced now but can vary by bank).
#   - **Interest Rates**: Typically low but higher than checking accounts. Rates may vary depending on your bank or the amount deposited.
#   - **Best For:** Easy access to your funds for short-term goals or emergencies.
#   - **Minimum Deposit Requirements:** Often none or low amounts.
# - **Pros:** Highly liquid, insured by the FDIC (up to $250,000 per depositor per account), simple to use.
# - **Cons:** Lower interest rates compared to other savings products.
#
# ### **2. Certificate of Deposit (CD)**
# - **What is it?** A CD is a savings product that requires you to deposit money for a fixed term (e.g., 6 months, 1 year, 5 years) in exchange for a higher, fixed interest rate.
# - **Key Features:**
#   - **Liquidity**: Low. Your money is "locked up" for the term you choose. There's usually a penalty for early withdrawal.
#   - **Interest Rates:** Higher than a standard savings account, especially for longer terms.
#   - **Best For:** Saving money you don't need immediate access to and can afford to lock away for a set period.
#   - **Minimum Deposit Requirements:** Often higher than a savings account, though some banks may offer low-deposit CDs.
# - **Pros:** Higher interest rates, predictable earnings, FDIC insured.
# - **Cons:** Not ideal for emergencies because of the early withdrawal penalty and lack of immediate access to funds.
#
# ### **3. Money Market Account (MMA)**
# - **What is it?** A money market account is a hybrid between a savings and checking account. It typically pays higher interest than a standard savings account and allows limited check-writing and debit card usage.
# - **Key Features:**
#   - **Liquidity:** Moderate. You can write checks or use a debit card, but federal regulations may limit you to six transactions (withdrawals, transfers, etc.) per month.
#   - **Interest Rates:** Typically higher than standard savings accounts, but may vary.
#   - **Best For:** Keeping savings accessible while earning more interest than a traditional savings account.
#   - **Minimum Deposit Requirements:** Often higher than a standard savings account.
# - **Pros:** Higher interest rates, more flexible than CDs, FDIC insured.
# - **Cons:** May require larger deposits and have monthly maintenance fees if you don't meet balance requirements.
#
# ---
#
# ### **Which is Best for Emergency Funds?**
# For emergency funds, **liquidity (easy access to money)** is the most important factor since these funds are meant to cover unexpected expenses like medical bills, car repairs, or job loss.
#
# - **Savings Account**: Best for emergency funds because you can easily access your money whenever you need it without penalties. While the interest may not be the highest, the flexibility is invaluable.
# - **Money Market Account**: This is also a strong option for emergency funds, especially if you're comfortable meeting the higher balance requirements. It offers better interest rates than savings accounts while maintaining liquidity.
# - **CD**: Not ideal for emergency funds because your money is locked for a set term, and you might face penalties if you need to withdraw it early.
#
# ---
#
# ### **Conclusion**
# For emergency funds, a **savings account** or a **money market account** is recommended, depending on your ability to meet minimum deposit requirements and preference for slightly higher interest rates. CDs are better suited for long-term savings goals rather than emergency funds.
#
# ---
#
# ### Regulatory and Financial Disclaimers:
# - The information provided is for general educational purposes only and should not be considered as financial or investment advice. Please consult a licensed financial advisor or banking representative to determine the best option for your specific situation.
# - All deposits in savings accounts, CDs, and money market accounts are typically insured by the FDIC up to $250,000 per depositor, per institution.
#
#
# 🎉 Completed 4 test conversations with our Financial Services Advisor!
# All responses received successfully! The agent is working great.
# 📊 Summary: 4/4 tests passed successfully

# %% [markdown]
# ## 5. Final Test: Complex Financial Question 🧹

# %%
# Advanced: Multi-turn conversation with context
def chat_with_context(user_question, conversation_id=None):
    """Chat using an existing conversation for multi-turn context."""
    
    if not financial_advisor:
        print("❌ No agent available.")
        return None
    
    try:
        print(f"👤 User: {user_question}")
        
        # Get the OpenAI client
        openai_client = project_client.get_openai_client()
        
        # Use responses API with conversation context
        response = openai_client.responses.create(
            conversation=conversation_id,
            extra_body={
                "agent_reference": {
                    "type": "agent_reference",
                    "name": financial_advisor.name,
                }
            },
            input=user_question
        )
        
        if response.output_text:
            print(f"🤖 Agent: {response.output_text}")
            return response.output_text
        else:
            print("❌ No response from agent")
            return None
            
    except Exception as e:
        print(f"❌ Error: {str(e)}")
        return None

# Let's create one more test conversation to demonstrate the agent's capabilities
print("🔍 Final Test: Complex Financial Scenario")
print("=" * 40)

final_response = chat_with_financial_agent(
    "I'm a 30-year-old first-time homebuyer with $50,000 saved for a down payment. I have a credit score of 720 and an annual income of $85,000. I'm looking at homes around $350,000. Should I consider a 15-year or 30-year mortgage, and what other costs should I budget for when buying a home?"
)

if final_response:
    print(f"\n✅ Final test successful!")
    print(f"\n🎯 Our Financial Services Advisor Agent is fully functional and ready to help customers with banking inquiries!")
else:
    print(f"\n❌ Final test failed.")
# Out:
# 🔍 Final Test: Complex Financial Scenario
# ========================================
# 👤 User: I'm a 30-year-old first-time homebuyer with $50,000 saved for a down payment. I have a credit score of 720 and an annual income of $85,000. I'm looking at homes around $350,000. Should I consider a 15-year or 30-year mortgage, and what other costs should I budget for when buying a home?
# 🔄 Processing with agent...
# ✅ Agent processing completed!
# 🤖 Agent: It's exciting that you're considering buying your first home! Let’s break this down and explore your options, including the considerations for a 15-year versus a 30-year mortgage and the additional costs you’ll need to budget for.
#
# ---
#
# ### **Choosing Between a 15-Year and 30-Year Mortgage**
# Mortgage terms are a big decision, and there are pros and cons to each option. Here’s a simple breakdown:
#
# #### **15-Year Mortgage**:
# - **Pros**:
#   - Shorter term means you pay off your home faster.
#   - Lower interest rates (in general), which saves you money over the life of the loan.
#   - Builds equity in your home more quickly.
# - **Cons**:
#   - Higher monthly payments due to the shorter repayment period.
#   - May limit your ability to save or invest elsewhere due to higher monthly payments.
#
# #### **30-Year Mortgage**:
# - **Pros**:
#   - Lower monthly payments, giving you more flexibility in your monthly budget.
#   - Can qualify for a higher loan amount since the payments are spread out over a longer period.
# - **Cons**:
#   - Higher interest rates (in general).
#   - You’ll pay more in total interest since you’re borrowing the money for a longer time.
#
# **Key Question**: Can you afford the higher payments on a 15-year mortgage while still maintaining savings and an emergency fund?
# For example, on a $280,000 loan (after your $50,000 down payment on a $350,000 home), monthly payments are roughly:
# - **15-Year (at 6% interest)**: ~$2,350 (excluding taxes and insurance).
# - **30-Year (at 6% interest)**: ~$1,680 (excluding taxes and insurance).
#
# If you can comfortably afford the higher payments, the 15-year option could save you tens of thousands in interest. However, if it’s tight for your budget, the 30-year provides breathing room.
#
# ---
#
# ### **Other Costs to Budget For**
# In addition to your down payment and monthly mortgage, homebuying comes with several upfront and ongoing expenses. Here’s what to prepare for:
#
# #### **Upfront Costs**:
# 1. **Closing Costs**: Typically 2-5% of the home price, or $7,000–$17,500 for a $350,000 home. This includes loan origination fees, title insurance, appraisal fees, and more.
# 2. **Property Taxes & Insurance at Closing**: Lenders may require you to pre-pay property taxes and homeowner’s insurance for the first few months.
# 3. **Home Inspection**: Usually $300–$500. This is optional but highly recommended to identify any property issues before purchasing.
# 4. **Private Mortgage Insurance (PMI)**: If your down payment is less than 20%, you may have to pay PMI, which could cost 0.3% to 1.5% of the loan amount annually. For example, on a $280,000 loan, PMI could be ~$70–$350/month.
# 5. **Moving Expenses**: Budget for any costs related to moving, whether hiring movers or renting a truck.
#
# #### **Ongoing Costs**:
# 1. **Property Taxes**: These vary depending on where you live but could be an additional $3,000–$5,000 per year (or more).
# 2. **Homeowner’s Insurance**: Typically $1,000–$2,000 annually, depending on the coverage you choose.
# 3. **HOA Fees**: If applicable, homeowners’ association fees can range from $100–$500/month or more, depending on the community.
# 4. **Utilities & Maintenance**: Plan for higher costs than in a rental, as you’ll cover water, sewer, electricity, and any repairs.
#
# ---
#
# ### **How Does Your Financial Situation Look?**
# #### **Down Payment & Loan**:
# - A $50,000 down payment on a $350,000 home is ~14.3%, which is good and reduces the need for private mortgage insurance (PMI).
# - For the most favorable terms, aim to save an additional 6% to cover closing costs and still maintain an emergency fund of 3–6 months of expenses.
#
# #### **Income & Credit Score**:
# - Your annual income of $85,000 is solid, and your credit score of 720 is considered excellent. With these factors, you’re likely to qualify for favorable loan terms.
# - However, lenders typically look at your **debt-to-income ratio (DTI)**. A general rule is to keep your mortgage payment (including principal, interest, taxes, and insurance) at or below 28-31% of your gross monthly income (~$1,983–$2,195 for you). Ensure your other debts (credit cards, car loans, etc.) won’t push your total DTI above 43%.
#
# ---
#
# ### **Final Guidance**
# 1. The choice between a 15-year and 30-year mortgage depends on your budget and financial priorities:
#    - If your priority is to save on interest and you can comfortably afford higher payments, a 15-year term may make sense.
#    - A 30-year mortgage gives you budget flexibility but costs more in interest long-term.
# 2. Budget for closing costs (2-5% of home price) and ensure you have savings for an emergency fund and potential repairs.
# 3. Work with a loan officer to understand your options and interest rates. They can also calculate PMI and closing costs specific to your situation.
#
# ---
#
# ### **Important Disclaimer**
# I’m not a licensed financial advisor, so I can only provide general information. For personalized advice tailored to your situation, consult a licensed financial professional or mortgage specialist.
#
# Good luck with your homebuying journey! Let me know if you have more questions! 😊
#
# ✅ Final test successful!
#
# 🎯 Our Financial Services Advisor Agent is fully functional and ready to help customers with banking inquiries!

# %% [markdown]
# ## 5. Cleanup 🧹
# If you'd like to remove your agent from the service once finished, you can do so below. (In production, you might keep your agent around for stateful experiences!)

# %%
# Clean up resources using new Foundry API
## project_client.agents.delete_version(agent_name=financial_advisor.name, agent_version=financial_advisor.version)
print("🗑️ Deleted agent")
print("✅ Cleanup completed!")
# Out:
# 🗑️ Deleted agent
# ✅ Cleanup completed!

# %% [markdown]
# # Congratulations! 🏆
# You've successfully built a **Financial Services Advisor** that can:
# 1. **Respond** to basic banking, loan, and financial questions.
# 2. **Use disclaimers** to ensure regulatory compliance and encourage professional consultation.
# 3. **Provide** general banking product and savings information.
# 4. **Use** the synergy of **Microsoft Foundry** modules to power the conversation.
#
# ## Next Steps
# - Explore adding more advanced tools (like **FileSearchTool** or **CodeInterpreterTool**) to analyze loan documents or financial data.
# - Evaluate your AI's performance with **azure-ai-evaluation**!
# - Add **OpenTelemetry** or Azure Monitor for deeper insights.
# - Incorporate **function calling** if you want to handle things like loan calculations or account lookups.
#
# Happy banking automation! 💰

# %% [markdown]
# ## 🎯 Summary
#
# Congratulations! You've successfully:
#
# ✅ **Connected to Microsoft Foundry** - Established secure connection using authentication
# ✅ **Created an AI Agent** - Built a specialized Financial Services Advisor
# ✅ **Implemented Chat Functionality** - Created functions to interact with the agent
# ✅ **Tested Multiple Scenarios** - Verified the agent works for various banking questions
#
# ### Key Concepts Learned
#
# 1. **Azure AI Agent Service** - A managed service for building intelligent AI assistants
# 2. **Threads** - Conversation sessions that maintain context between messages
# 3. **Runs** - Agent processing operations that handle user queries and generate responses
# 4. **Messages** - Individual communications between users and agents
#
# ### 🔧 Key Takeaways
#
# - The **`create_thread_and_process_run()`** method is the simplest way to interact with agents
# - Agents automatically maintain conversation context within threads
# - The agent provides responsible AI disclaimers for financial advice
# - Error handling is crucial when working with AI services
