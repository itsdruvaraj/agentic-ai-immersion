# %% [markdown]
# # 🔌 Agents with Foundry MCP Server
#
# Welcome to our **Foundry MCP Server** tutorial! In this notebook, we'll demonstrate how to:
#
# 1. **Understand** the Foundry MCP Server and its capabilities
# 2. **Configure** an MCP tool connection in Microsoft Foundry
# 3. **Create an Agent** with MCP tools to access Foundry capabilities
# 4. **Handle MCP approval requests** for secure tool access
#
# ### 🔌 What is Foundry MCP Server?
# > [Foundry MCP Server](https://learn.microsoft.com/azure/ai-foundry/mcp/get-started) is a **cloud-hosted MCP service** at `https://mcp.ai.azure.com` that provides:
# > - **Model Discovery**: Explore and compare models from the Foundry catalog
# > - **Model Deployment**: Check quotas and deploy models
# > - **Agent Management**: Create and manage AI agents
# > - **Evaluation**: Run evaluations and quality assessments
# > - **Knowledge Integration**: Work with Azure AI Search indexes
#
# ### 🌟 Why Foundry MCP Server?
# | Feature | Benefit |
# |---------|---------|
# | **Cloud-hosted** | No local server setup required |
# | **Entra ID Authentication** | Secure OAuth 2.0 with user-specific permissions |
# | **Curated Tools** | Pre-built tools for common Foundry operations |
# | **Scalable** | Built with cloud-scale reliability |
#
# ## Prerequisites
# - Microsoft Foundry project with appropriate permissions
# - **Foundry MCP Server connection** configured in your project (see setup below)
# - A `.env` file in the parent directory containing:
#   ```bash
#   AI_FOUNDRY_PROJECT_ENDPOINT=<your-ai-foundry-project-endpoint>
#   AZURE_AI_MODEL_DEPLOYMENT_NAME=<supported-model>
#   TENANT_ID=<your-azure-tenant-id>
#   FOUNDRY_MCP_CONNECTION_ID=<connection-id-from-foundry-portal>  # See setup below
#   ```
#
# ## ⚙️ Setting up Foundry MCP Server Connection
#
# **Important**: Before using MCP tools in code, you must create a connection in the Foundry portal:
#
# ### Step 1: Navigate to Foundry Tools
# 1. Go to [Microsoft Foundry portal](https://ai.azure.com)
# 2. Select your project
# 3. Navigate to **Build** → **Tools**
#
# ### Step 2: Add Foundry MCP Server
# 1. Click **Add tool** → **Catalog**
# 2. Search for "Foundry MCP Server (preview)"
# 3. Select it and click **Create**
# 4. The connection will be created with OAuth authentication
#
# ### Step 3: Get Connection ID
# 1. After creating the connection, click on it to view details
# 2. Copy the **Project connection ID** from the details page
# 3. Add it to your `.env` file as `FOUNDRY_MCP_CONNECTION_ID`
#
# <img src="seq-diagrams/foundry-mcp-connection-id.png" width="80%"/>
#
# > **Note**: The Project connection ID follows this format:
# > `/subscriptions/{subscription-id}/resourceGroups/{rg}/providers/Microsoft.CognitiveServices/accounts/{account}/projects/{project}/connections/FoundryMCPServerpreview`
#
# ## Architecture Overview
# ```
# ┌─────────────────┐     ┌──────────────────┐     ┌─────────────────────────┐
# │   User Query    │────▶│   Agent + MCP    │────▶│  Foundry MCP Server     │
# │                 │     │     Tool         │     │  (mcp.ai.azure.com)     │
# └─────────────────┘     └──────────────────┘     └─────────────────────────┘
#                               │                           │
#                               ▼                           ▼
#                     ┌──────────────────┐       ┌─────────────────────────┐
#                     │  Connection ID   │       │  - Model Catalog        │
#                     │  (from portal)   │       │  - Deployments          │
#                     └──────────────────┘       │  - Evaluations          │
#                                                │  - Agent Service        │
#                                                └─────────────────────────┘
# ```
#
# ## Available Tool Categories
#
# | Category | Tools | Description |
# |----------|-------|-------------|
# | **Models** | `model_catalog_list`, `model_deploy` | Explore and deploy models |
# | **Evaluation** | `evaluation_create`, `evaluation_get` | Run and review evaluations |
# | **Agents** | `agent_update`, `agent_list` | Manage AI agents |
# | **Knowledge** | `index_list`, `query_index` | Work with AI Search |
#
# 📚 **Learn More**: [Foundry MCP Server Documentation](https://learn.microsoft.com/azure/ai-foundry/mcp/get-started)

# %% [markdown]
# ## 🔐 Authentication Setup
#
# Before running the next cell, make sure you're authenticated with Azure CLI. Run this command in your terminal:
#
# ```bash
# az login --use-device-code
# ```
#
# This will provide you with a device code and URL to authenticate in your browser, which is useful for:
# - Remote development environments
# - Systems without a default browser
# - Corporate environments with strict security policies
#
# After successful authentication, you can proceed with the notebook cells below.

# %% [markdown]
# ## 1. Initial Setup
# We'll load environment variables from `.env` and initialize our **AIProjectClient** to manage agents with MCP tools.

# %%
import os
from pathlib import Path

from dotenv import load_dotenv
from azure.identity import AzureCliCredential
from azure.ai.projects import AIProjectClient
from azure.ai.projects.models import (
    PromptAgentDefinition,
    MCPTool,
)
from openai.types.responses.response_input_param import (
    McpApprovalResponse,
    ResponseInputParam,
)

# Load environment variables from parent .env
notebook_path = Path().absolute()
parent_dir = notebook_path.parent
load_dotenv(parent_dir.parent / '.env')

# Get configuration
tenant_id = os.environ.get("TENANT_ID")
project_endpoint = os.environ.get("AI_FOUNDRY_PROJECT_ENDPOINT")
model_deployment = os.environ.get("AZURE_AI_MODEL_DEPLOYMENT_NAME", "gpt-4o")

# Foundry MCP Server connection ID (configured in Foundry portal)
foundry_mcp_connection_id = os.environ.get("FOUNDRY_MCP_CONNECTION_ID")

print("🔌 Foundry MCP Server Notebook")
print("=" * 60)
print(f"🔑 Tenant ID: {tenant_id}")
print(f"📍 Project Endpoint: {project_endpoint}")
print(f"🤖 Model Deployment: {model_deployment}")
print("")
print("🔌 Foundry MCP Server: https://mcp.ai.azure.com")
print(f"✅ Connection ID: {foundry_mcp_connection_id}")
# Out:
# 🔌 Foundry MCP Server Notebook
# ============================================================
# 🔑 Tenant ID: 978bbad2-037f-4859-8a78-385d36d264ee
# 📍 Project Endpoint: https://mfbr-ext-eus2-aiml-profx-01.services.ai.azure.com/api/projects/mfbp-ext-eus2-aiml-profx-01
# 🤖 Model Deployment: gpt-4o
#
# 🔌 Foundry MCP Server: https://mcp.ai.azure.com
# ✅ Connection ID: /subscriptions/bbb15ed9-2e3a-4839-9ac5-b166cb3e4cde/resourceGroups/rg-ext-eus2-aiml-profx-01/providers/Microsoft.CognitiveServices/accounts/mfbr-ext-eus2-aiml-profx-01/projects/mfbp-ext-eus2-aiml-profx-01/connections/FoundryMCPServerpreview

# %% [markdown]
# ## 2. Initialize the AI Project Client
# Create the AIProjectClient with Azure CLI-based authentication.

# %%
# Initialize AIProjectClient with Azure CLI authentication
print("🔐 Using Azure CLI authentication...")
print("   Make sure you've run 'az login' in your terminal first!")
print("")

credential = AzureCliCredential(tenant_id=tenant_id, process_timeout=30)

# Create the project client
project_client = AIProjectClient(
    endpoint=project_endpoint,
    credential=credential
)

# Get the OpenAI client for conversations
openai_client = project_client.get_openai_client()

print("✅ AIProjectClient initialized with AzureCliCredential")
print("✅ OpenAI client ready for conversations")
# Out:
# 🔐 Using Azure CLI authentication...
#    Make sure you've run 'az login' in your terminal first!
#
# ✅ AIProjectClient initialized with AzureCliCredential
# ✅ OpenAI client ready for conversations

# %% [markdown]
# ## 3. Define the Foundry MCP Tool
#
# The **Foundry MCP Server** is hosted at `https://mcp.ai.azure.com` and provides a curated set of tools for interacting with Microsoft Foundry services.
#
# ### Key Parameters:
# - **server_label**: Identifies the MCP server (e.g., `"foundry-mcp"`)
# - **server_url**: `https://mcp.ai.azure.com/sse` - the cloud-hosted Foundry MCP SSE endpoint
# - **require_approval**: Controls approval flow (`"always"`, `"never"`) - use `"never"` for simpler workflows
# - **project_connection_id**: **Required** - Connection configured in Foundry portal
#
# ### 🔐 Authentication Flow:
# 1. You configure the MCP connection in Microsoft Foundry portal
# 2. The portal stores authentication (OAuth/Entra ID)
# 3. Your code references the connection via `project_connection_id`
# 4. The agent uses the stored credentials for secure access
#
# ### Foundry MCP Server Tools:
#
# | Tool | Description |
# |------|-------------|
# | `model_catalog_list` | List models from Microsoft Foundry catalog |
# | `model_deploy` | Deploy a model to Azure AI Services |
# | `model_quota_list` | Check quota availability |
# | `evaluation_create` | Create an evaluation run |
# | `agent_update` | Create or update an agent |
# | `index_list` | List Azure AI Search indexes |

# %%
# Define Foundry MCP Server tool configuration
print("🔌 Configuring Foundry MCP Server tool...")
print("")

# Configure MCP tool with the portal connection
# The server_url should match the "Remote MCP server endpoint" from your connection
mcp_tool = MCPTool(
    server_label="foundry-mcp",
    server_url="https://mcp.ai.azure.com/sse",  # SSE endpoint for MCP protocol
    require_approval="never",  # Skip approval flow for simpler demo
    project_connection_id=foundry_mcp_connection_id,  # Connection for auth
)

print(f"✅ Foundry MCP Tool configured:")
print(f"   Server Label: {mcp_tool.server_label}")
print(f"   Server URL: {mcp_tool.server_url}")
print(f"   Require Approval: {mcp_tool.require_approval}")
print(f"   Connection ID: {mcp_tool.project_connection_id}")
# Out:
# 🔌 Configuring Foundry MCP Server tool...
#
# ✅ Foundry MCP Tool configured:
#    Server Label: foundry-mcp
#    Server URL: https://mcp.ai.azure.com/sse
#    Require Approval: never
#    Connection ID: /subscriptions/bbb15ed9-2e3a-4839-9ac5-b166cb3e4cde/resourceGroups/rg-ext-eus2-aiml-profx-01/providers/Microsoft.CognitiveServices/accounts/mfbr-ext-eus2-aiml-profx-01/projects/mfbp-ext-eus2-aiml-profx-01/connections/FoundryMCPServerpreview

# %% [markdown]
# ## 4. Create an Agent with MCP Tools
#
# Now we'll create an agent that can use MCP tools to access Foundry capabilities.

# %%
# Define agent instructions for using Foundry MCP Server
agent_name = "foundry-mcp-assistant"

agent_instructions = """
You are an AI Development Assistant with access to Microsoft Foundry capabilities via MCP tools.

Your capabilities include:
1. 📊 Exploring AI models from the Foundry catalog
2. 🚀 Helping with model deployment and quota management
3. 📈 Running evaluations on AI applications
4. 🤖 Managing AI agents in the Foundry ecosystem
5. 🔍 Working with Azure AI Search indexes

When helping users:
- Recommend appropriate models for their use cases (e.g., GPT-4o for complex reasoning, Phi-4 for edge deployments)
- Explain model capabilities, benchmarks, and licensing
- Guide through deployment processes
- Help set up evaluations for quality and safety
- Assist with knowledge base integrations

⚠️ IMPORTANT NOTES:
- Model deployments may require appropriate quota allocations
- Evaluations consume compute resources
- Always verify permissions before making changes
"""

print(f"📝 Agent Name: {agent_name}")
print(f"📋 Instructions length: {len(agent_instructions)} characters")
# Out:
# 📝 Agent Name: foundry-mcp-assistant
# 📋 Instructions length: 861 characters

# %%
# Create the agent with MCP tool
print(f"Creating Foundry MCP Assistant Agent...")

# Create agent with Foundry MCP Server tool
agent_definition = PromptAgentDefinition(
    model=model_deployment,
    instructions=agent_instructions,
    tools=[mcp_tool],
)

# Create the agent version
agent = project_client.agents.create_version(
    agent_name=agent_name,
    definition=agent_definition,
)

print(f"✅ Agent created: {agent.name} (Version: {agent.version})")
print("🔌 Agent configured with Foundry MCP Server tool")
print("")
print("🎯 This agent can now access Foundry MCP Server capabilities:")
print("   • Model exploration and recommendations")
print("   • Deployment management")
print("   • Evaluation orchestration")
print("   • Agent management")
# Out:
# Creating Foundry MCP Assistant Agent...
# ✅ Agent created: foundry-mcp-assistant (Version: 3)
# 🔌 Agent configured with Foundry MCP Server tool
#
# 🎯 This agent can now access Foundry MCP Server capabilities:
#    • Model exploration and recommendations
#    • Deployment management
#    • Evaluation orchestration
#    • Agent management

# %% [markdown]
# ## 5. Create a Conversation
#
# Create a conversation thread to maintain context across interactions.

# %%
# Create a conversation for the chat session
print("Creating conversation for the chat session...")

conversation = openai_client.conversations.create()

print(f"✅ Conversation created: {conversation.id}")
# Out:
# Creating conversation for the chat session...
# ✅ Conversation created: conv_af0aa5597aa7fef800f3cbDe0JX0YsrBYYQb43kq1XXBb1Y18M

# %% [markdown]
# ## 6. Query the Agent with Foundry MCP Tools
#
# When the agent uses Foundry MCP tools, you may receive **approval requests**. This is a security feature of the Foundry MCP Server that ensures users approve operations before they execute.
#
# ### MCP Approval Flow:
# 1. Send a query to the agent (e.g., "What models are available?")
# 2. Agent calls Foundry MCP Server tool (e.g., `model_catalog_list`)
# 3. Server returns an `mcp_approval_request`
# 4. Client sends back an `mcp_approval_response` (approve/deny)
# 5. Agent receives data and responds to user
#
# ### Example Prompts for Foundry MCP Server:
# - "What OpenAI models are available in Microsoft Foundry?"
# - "Compare Phi models and explain their differences"
# - "What models are good for reasoning tasks?"
# - "Help me understand model quotas for my subscription"

# %%
def process_mcp_response(openai_client, agent, initial_response, auto_approve=True):
    """
    Process a response that may contain MCP approval requests.
    
    Args:
        openai_client: The OpenAI client instance
        agent: The agent being used
        initial_response: The initial response from the agent
        auto_approve: Whether to automatically approve MCP requests
    
    Returns:
        The final response after processing any approvals
    """
    response = initial_response
    
    # Check for MCP approval requests
    approval_requests = []
    for item in response.output:
        if item.type == "mcp_approval_request":
            print(f"\n🔐 MCP Approval Request Received:")
            print(f"   Server: {item.server_label}")
            print(f"   Request ID: {item.id}")
            
            if auto_approve and item.id:
                print(f"   ✅ Auto-approving request...")
                approval_requests.append(
                    McpApprovalResponse(
                        type="mcp_approval_response",
                        approve=True,
                        approval_request_id=item.id,
                    )
                )
            else:
                print(f"   ❌ Request denied or missing ID")
    
    # If we have approvals to send, send them
    if approval_requests:
        print(f"\n📤 Sending {len(approval_requests)} approval response(s)...")
        
        response = openai_client.responses.create(
            input=approval_requests,
            previous_response_id=response.id,
            extra_body={"agent_reference": {"name": agent.name, "type": "agent_reference"}},
        )
        
        print("✅ Approval response sent")
    
    return response

print("✅ MCP response processing function defined")
# Out:
# ✅ MCP response processing function defined

# %%
# Sample queries that leverage Foundry MCP Server capabilities
queries = [
    "What AI models would you recommend for document analysis use cases?",
    "Explain how the Foundry MCP Server helps with AI development workflows.",
    "What security features does the Foundry MCP Server provide for enterprise use?",
]

print("💬 Foundry MCP Server Assistant Session")
print("=" * 60)

for i, query in enumerate(queries, 1):
    print(f"\n📝 Query {i}: {query}")
    print("-" * 50)
    
    # Send the query
    response = openai_client.responses.create(
        conversation=conversation.id,
        input=query,
        extra_body={"agent_reference": {"name": agent.name, "type": "agent_reference"}},
    )
    
    # Process any MCP approval requests
    response = process_mcp_response(openai_client, agent, response)
    
    # Display the response
    print(f"\n🤖 Agent Response:")
    print(response.output_text if response.output_text else "No response text")
    print("\n" + "=" * 60)
# Out:
# 💬 Foundry MCP Server Assistant Session
# ============================================================
#
# 📝 Query 1: What AI models would you recommend for document analysis use cases?
# --------------------------------------------------
#
# 🤖 Agent Response:
# For **document analysis use cases**, you would generally need AI models that excel in natural language understanding (NLU), text extraction, summarization, and question-answering. Here are some recommended models based on their suitability:
#
# ---
#
# ### **1. GPT-4/OpenAI GPT-3.5**
#    - **Capabilities**:
#      - Understanding complex language structures
#      - Summarizing lengthy documents
#      - Answering questions based on document content
#      - Generating insights/context-aware responses
#    - **Strengths**: Excellent for both structured and unstructured text analysis.
#    - **Suggested Deployment**: Azure OpenAI's **GPT-4o** or **GPT-3.5 Turbo** for optimized cost and performance.
#
# ---
#
# ### **2. Azure Cognitive Search with AI Enrichment**
#    - **Capabilities**:
#      - Built-in text extraction from PDFs and scanned documents
#      - Preprocessing for structured search index creation
#      - Knowledge mining with cognitive skills
#    - **Strengths**: Ideal for rich search and metadata-driven analysis for document-heavy use cases (e.g., contracts, invoices, or academic papers).
#
# ---
#
# ### **3. LayoutLM (Amazon or Microsoft Foundry)**
#    - **Capabilities**:
#      - Specialized in structured and semi-structured document understanding (e.g., tables, forms, receipts).
#      - Extracts data from complex document layouts combining vision and text inputs.
#    - **Best For**:
#      - Form recognition and processing (e.g., invoices, loan applications).
#      - Bank statement analysis.
#
# ---
#
# ### **4. Phi-1.5 or Phi-4 (Edge Use Cases)**
#    - **Capabilities**:
#      - Fine-tuned for low-latency, edge-ready deployments.
#      - Suitable for tasks requiring light compute power at endpoints.
#    - **Best For**: On-device document processing or lightweight workflows.
#
# ---
#
# ### **5. Microsoft Turing Models**
#    - **Turing NLG**:
#      - Excellent for summarization and document creation use cases.
#    - **Turing Document Understanding** (DU):
#      - Built for intelligent document classification and entity recognition.
#    - **Best For**: Enterprise business document workflows (e.g., contracts, RFP analysis).
#
# ---
#
# ### **6. BERT/DistilBERT Variants**
#    - **Capabilities**:
#      - Extractive question-answering (e.g., FAQs, knowledge base search).
#      - Contextual text embeddings for search matching.
#    - **Best For**: More traditional, resource-constrained NLP projects.
#
# ---
#
# ### Considerations for Choice:
#    - **Summarization**: Models like GPT or Turing NLG are strong.
#    - **Question-Answering**: GPT-4 or BERT-based models work well.
#    - **Form-based Analysis**: LayoutLM is top-notch for forms, invoices, and table-heavy documents.
#    - **Search and Indexing**: Azure Cognitive Search for fast retrieval combined with AI enrichment.
#
# ---
#
# Let me know more about your document analysis use case (e.g., contracts, legal, forms, reports), and I can refine the recommendations further or assist with deployment!
#
# ============================================================
#
# 📝 Query 2: Explain how the Foundry MCP Server helps with AI development workflows.
# --------------------------------------------------
#
# 🤖 Agent Response:
# The Foundry MCP Server is a comprehensive platform that accelerates **AI development workflows** by providing tools and functionalities to build, deploy, manage, and evaluate AI models and agents at scale. Here’s how it boosts efficiency in AI development:
#
# ---
#
# ### **1. Model Discovery and Recommendation**
#    - **Model Catalog**: Access a wide range of pre-trained models including GPT series, Phi-series, Turing models, and models fine-tuned for specific applications (e.g., document analysis, conversational AI).
#    - **Recommendations**: Suggests optimal models based on use cases (e.g., text generation, summarization, multi-modal tasks).
#    - **Model Details**: Offers benchmarks, licensing information, and capabilities comparisons for informed decision-making.
#
# ---
#
# ### **2. Model Management and Deployment**
#    - **Deployment Framework**:
#      - Deploy large-scale AI models on Microsoft Azure with infrastructure optimized for latency, scalability, and redundancy.
#      - Supports **auto-scaling** based on demand through SKU and instance allocation.
#    - **Quota Management**:
#      - Ensures resource limits (compute, token usage, etc.) are well-utilized within subscription constraints.
#    - **Switch Recommendations**:
#      - Offers insights into similar models or optimal model alternatives based on efficiency, cost, quality scores, safety metrics, and upcoming deprecation statuses.
#
# ---
#
# ### **3. Agent Development and Containerization**
#    - **Agent Creation**:
#      - Enables development of **prompt-based AI agents** and **container-based hosted agents** for custom workflows via logical schema definitions.
#    - **Containerized Execution**:
#      - Supports controlled environments for hosted agents (e.g., memory and CPU specifications) with container lifecycle management for deployment, scaling, and termination.
#    - **Invoke and Test Agents**:
#      - Allows real-time testing and debugging for agents, ensuring functional correctness and robustness.
#
# ---
#
# ### **4. Data and Dataset Management**
#    - **Dataset Uploading**:
#      - Upload or reference datasets from cloud storage (Azure Blob Storage, etc.) to use in fine-tuning or evaluations.
#    - **Synthetic Data Generation**:
#      - Auto-generates evaluation or training datasets using LLM-based synthetic query generation (e.g., Q&A pair creation).
#
# ---
#
# ### **5. Evaluation and Benchmarking**
#    - **Batch Evaluations**:
#      - Evaluate AI agents or models against annotated benchmark datasets or live query data.
#      - Supports tests for safety (violence, hate speech), quality (relevance, coherence), and tool accuracy (e.g., tool output/utilization).
#    - **Continuous Evaluation**:
#      - Tracks agent/model performance over time with custom metrics and regular evaluations to ensure sustained quality.
#    - **LLM Judge Evaluators**:
#      - Uses state-of-the-art language models to evaluate quality metrics like coherence, fluency, relevance, and accuracy.
#
# ---
#
# ### **6. Collaborative Development**
#    - **Connections and Integrations**:
#      - Links external tools like **Azure Cognitive Search**, **Custom APIs**, **Blob Storage**, etc., for seamless integration with external data sources and compute environments.
#    - **Agent Session Management**:
#      - Provides isolated environments (sessions) to upload files, execute workflows, and download results without affecting other agents.
#    - **Metadata-Driven Insights**:
#      - Tags evaluations, datasets, and agents with meaningful metadata for tracking and reuse.
#
# ---
#
# ### **7. Safety and Scalability**
#    - **Safety Metrics**:
#      - Evaluates safety parameters such as hate/unfairness, toxicity, and code vulnerability.
#    - **Scalability**:
#      - Handles enterprise-grade workloads by leveraging Azure's globally distributed infrastructure for compute availability.
#
# ---
#
# ### **8. Workflow Automation**
#    - Tools like **evaluation suites** and **adaptive evaluators** automate testing, quality tuning, and optimization. This ensures your models or agents are consistently improving.
#
# ---
#
# ### **Key Benefits**
# - **Faster Development:** Pre-built tools for data, deployment, and evaluation reduce cycle times.
# - **Enterprise Scalability:** Optimized workflows for production-ready AI solutions.
# - **Insightful Analytics:** Evaluations guide iterative improvements for better user experiences.
# - **Cost Efficiency:** Resource allocation and quota management prevent unnecessary expenses.
#
# ---
#
# Let me know if you want a specific example, like **running a mass evaluation against a dataset** or **optimizing a large-scale model deployment**!
#
# ============================================================
#
# 📝 Query 3: What security features does the Foundry MCP Server provide for enterprise use?
# --------------------------------------------------
#
# 🤖 Agent Response:
# The Foundry MCP Server is designed with enterprise-grade **security** and **compliance** measures to ensure that AI deployments remain secure, scalable, and trustworthy. Here’s an overview of its **key security features**:
#
# ---
#
# ### **1. Secure Data Management**
#    - **Encrypted Data Transmission:**
#      - All data transfers between clients and the Foundry MCP Server are secured using TLS (Transport Layer Security) to prevent eavesdropping and data interception.
#    - **Data Encryption at Rest:**
#      - Any stored data (e.g., datasets, logs, deployment files) is encrypted using robust encryption mechanisms (e.g., AES-256).
#    - **Temporary Data Handling (Sessions):**
#      - Hosted agent sessions manage isolated environments. Uploaded files and data are accessible only within their associated session and are securely deleted after use or expiration.
#
# ---
#
# ### **2. Role-Based Access Control (RBAC)**
#    - **Granular Permissions:**
#      - Admins can define fine-grained permissions for users and groups to control who can access specific agents, datasets, or evaluations.
#    - **Scoped Access:**
#      - Limits access to specific projects or endpoints based on the user’s assigned roles or scope, preventing accidental or unauthorized access.
#    - **Custom Roles:**
#      - Enterprises can define custom roles for specialized access to specific evaluation suites, datasets, or agents.
#
# ---
#
# ### **3. Secure Model Invocation**
#    - **Authenticated API Calls:**
#      - All API usage requires authentication through Azure Active Directory (AAD) or API keys. This ensures only authorized users/apps can interact with the system.
#    - **Session Isolation:**
#      - Hosted agents create isolated execution environments for model invocations, ensuring that user input and agent responses remain segregated between sessions.
#
# ---
#
# ### **4. Compliance with Enterprise Standards**
#    - **Data Residency:**
#      - Ensures that data stays in the specified Azure region to comply with data privacy laws such as GDPR or other region-specific regulations.
#    - **Audit Trail:**
#      - Maintains logs for all major operations (e.g., deployments, evaluations, dataset management) for transparency and accountability.
#    - **Certifications and Compliance:**
#      - Built on Microsoft’s Azure platform, Foundry MCP Server complies with global standards, including ISO 27001, GDPR, HIPAA, FedRAMP, and SOC 2.
#
# ---
#
# ### **5. Secure Connections**
#    - **Connection Authentication:**
#      - Supports various authentication mechanisms like:
#        - **API keys** (for project connections like Azure OpenAI).
#        - **Managed Identity** or **OAuth** (to avoid key-based credentials for Azure integrations).
#    - **Connection Metadata Validation:**
#      - Validates and stores connection-related metadata to ensure security integrity before linking external resources (e.g., Azure Blob Storage, Cognitive Search).
#
# ---
#
# ### **6. Model and Agent Security**
#    - **Containerized Agents:**
#      - Hosted agents run in containerized environments, isolated from the host machine and other services.
#    - **Secure Model Deployments:**
#      - Deployments are protected with defined quotas and throttles, ensuring models are not misused or overwhelmed with requests.
#    - **Model Access Restrictions:**
#      - Allows you to restrict access to specific deployed models based on user roles or integrated applications.
#
# ---
#
# ### **7. Content Safety Features**
#    - **Built-in Content Moderation:**
#      - Models can be evaluated and monitored using safety evaluators that filter toxic or sensitive content, such as:
#        - Hate speech
#        - Violence
#        - Self-harm
#        - Protected Material Violations
#    - **Content Filtering in Deployment:**
#      - Supports integrating content moderation pipelines to sanitize model responses before delivering to end users.
#
# ---
#
# ### **8. Monitoring and Alerts**
#    - **Quota and Usage Alerts:**
#      - Provides monitoring tools for quota consumption and throttling to detect unusual activity or potential misuse.
#    - **Real-Time Logging:**
#      - Streams logs with structured output for live monitoring and debugging.
#    - **Anomaly Detection:**
#      - Tracks response patterns from deployed agents or models for anomalies that may indicate misuse or attacks.
#
# ---
#
# ### **9. Secure Evaluation Workflows**
#    - **Evaluator Integrity:**
#      - Custom evaluators are secure, allowing sensitive or proprietary rubrics to remain hidden during evaluations.
#    - **Scoping Trace-Based Evaluations:**
#      - Traces (e.g., user-agent conversations) used for evaluations are encrypted and scoped within enterprise boundaries.
#
# ---
#
# ### **10. Deprecation Awareness and Updates**
#    - **Deprecation Warnings:**
#      - Models nearing deprecation or license expiration are flagged to avoid using outdated or unsupported models.
#    - **Model Updates:**
#      - Supports updating models securely without disrupting workflows or breaking compliance requirements.
#
# ---
#
# ### **11. AI Safety and Ethical Applications**
#    - **Adversarial Testing:**
#      - Supports adversarial input testing to detect vulnerabilities (e.g., prompt injection attacks).
#    - **Explainability & Transparency:**
#      - Tools for explaining AI responses or performance metrics to ensure responsible use and compliance with ethical standards.
#
# ---
#
# ### **12. Fail-Safe Mechanisms**
#    - **Traffic Throttling:**
#      - Protects against Distributed Denial of Service (DDoS) and brute-force attacks by enforcing request limits.
#    - **Graceful Degradation:**
#      - Ensures agents and models respond with fallback messages or remain offline if under attack or misused.
#
# ---
#
# ### Summary of Benefits:
# - Protects **data** and **intellectual property** with robust encryption and access controls.
# - Ensures compliance with major **industry regulations**.
# - Blocks security risks through **RBAC**, **secure integrations**, and **ethical AI tools**.
# - Monitors usage to detect and prevent misuse or fraudulent activities.
#
# Feel free to ask if you need more detail about any specific feature (e.g., **RBAC setup** or **secure connections**).
#
# ============================================================

# %% [markdown]
# ## 7. Interactive MCP Query (Optional)
#
# Try your own queries with the MCP-enabled agent.

# %%
# Interactive query - try Foundry MCP Server prompts
# Example prompts you can try:
# - "What are the most popular models in Microsoft Foundry?"
# - "Show me models with MIT license"
# - "What models from Meta are available?"
# - "Compare GPT-4o and Phi-4 for my use case"

custom_query = "What capabilities does the Foundry MCP Server provide for building AI agents?"

print(f"📝 Custom Query: {custom_query}")
print("-" * 50)

# Send the query
response = openai_client.responses.create(
    conversation=conversation.id,
    input=custom_query,
    extra_body={"agent_reference": {"name": agent.name, "type": "agent_reference"}},
)

# Process any MCP approval requests
response = process_mcp_response(openai_client, agent, response)

# Display the response
print(f"\n🤖 Agent Response:")
print(response.output_text if response.output_text else "No response text")
# Out:
# 📝 Custom Query: What capabilities does the Foundry MCP Server provide for building AI agents?
# --------------------------------------------------
#
# 🤖 Agent Response:
# The Foundry MCP Server offers **powerful tools and frameworks** for building, deploying, and managing **AI agents** across various workflows and business applications. These capabilities streamline the entire lifecycle of agent development, making it easier to create, test, and scale intelligent agents. Here’s an overview of how the Foundry MCP Server supports AI agent creation:
#
# ---
#
# ### **1. Types of Agents**
#    - **Prompt-Based Agents**:
#      - Lightweight, highly flexible AI agents that use natural language models (like GPT-4) combined with structured prompts for task-specific behavior.
#      - Example: A customer service chatbot that uses a tailored prompt for answering FAQs.
#
#    - **Hosted Container-Based Agents**:
#      - Fully containerized agents that run in isolated environments.
#      - Used for workflows requiring external tools, code-based integrations, or specific execution environments.
#      - Example: Agents using custom Python scripts to interact with APIs.
#
# ---
#
# ### **2. Agent Definition and Customization**
#    - **Agent Definition Schema**:
#      - Provides pre-defined templates for creating agents, including support for tools, memory, container management, and user-defined logic.
#    - **Tool Integrations**:
#      - Agents can integrate tools like Azure Cognitive Search, databases, or workflow APIs for advanced task execution.
#    - **Memory Management**:
#      - Supports conversational memory to enable multi-turn conversations with contextual understanding.
#    - **Custom Behaviors**:
#      - Define system prompts, response formatting, and specialized workflows tailored to unique application needs.
#
# ---
#
# ### **3. Agent Lifecycle Management**
#    - **Container Lifecycle**:
#      - Agents run in secure, containerized environments, supporting lifecycle actions like start, stop, scaling, and deletion.
#      - Provides reliable operation with **auto-scaling** for traffic bursts and **graceful degradation** to manage downtime.
#    - **Versioning**:
#      - Maintains multiple versions of agents, allowing you to deploy specific versions for testing or production without affecting live workflows.
#
# ---
#
# ### **4. Real-Time Agent Invocation**
#    - **Dynamic Message Handling**:
#      - Send user inputs dynamically and receive contextual, accurate responses.
#    - **Session Isolation**:
#      - Supports secure, isolated sessions for hosted environments so multiple users can interact with the agent concurrently.
#    - **Streaming Mode**:
#      - For real-time responsiveness, agents support streamed outputs for applications like virtual assistants.
#
# ---
#
# ### **5. Integration with AI Models**
#    - **Model Selection**:
#      - Choose optimized models for different agent use cases (e.g., GPT-4 for high-quality responses, Phi-4 for edge deployments).
#    - **Custom Model Deployments**:
#      - Agents can connect seamlessly with deployed models on Foundry MCP, taking advantage of advanced optimizations and compute resources.
#
# ---
#
# ### **6. Tool-Based Agents**
#    - **Built-in Tools**:
#      - Includes task-specific tools for computations, database queries, translations, and more.
#    - **Custom Tools**:
#      - Define custom tools, scripts, or workflows your agent can invoke at runtime for specialized requirements.
#    - **Toolchain Integration**:
#      - Execute runtime workflows for external APIs, document analyses, web scraping, or metadata extraction.
#
# ---
#
# ### **7. Workflow Automation**
#    - **Context-Aware Process Execution**:
#      - Agents can automate workflows by understanding hierarchical tasks and delegating follow-up operations.
#      - Example: A legal document review agent that reads through contracts, extracts key clauses, and flags risks.
#    - **Multi-Turn Conversations**:
#      - Conversational agents are capable of maintaining context across multiple turns, responding intelligently to follow-up queries or actions.
#
# ---
#
# ### **8. Batch and Continuous Evaluations**
#    - **Agent Performance Assessment**:
#      - Batch evaluations test an agent against preconfigured datasets.
#    - **Continuous Monitoring**:
#      - Automated and periodic evaluations to assess performance metrics like task completion, safety compliance, and quality.
#
# ---
#
# ### **9. Data Handling**
#    - **Synthetic Dataset Generation**:
#      - Generate synthetic queries and dataset entries for training or testing an agent.
#    - **JSON Schema Support**:
#      - Allows structured data inputs/output, making it easy to map agent capabilities to data pipelines.
#
# ---
#
# ### **10. Security and Scalability**
#    - **Scalability**:
#      - Designed for enterprise-grade deployments, enabling traffic handling from thousands of users.
#    - **Isolation**:
#      - Containerized environments ensure agents are isolated, secure, and operationally independent.
#    - **Robust Fail-Safes**:
#      - Handles user errors gracefully with fallback behaviors or defined response schemes.
#
# ---
#
# ### **11. Monitoring and Debugging**
#    - **Log Streaming**:
#      - Provides real-time access to container logs for debugging or actively monitoring agent behavior.
#    - **Trace Analysis**:
#      - Stores user-agent interactions (traces), which can be evaluated later using LLM judges or custom evaluators.
#    - **Performance Metrics**:
#      - Tracks agent response latency, throughput, and safety adherence for optimization.
#
# ---
#
# ### **12. Deployment and Scaling**
#    - **Deployment Models**:
#      - Deploy agents via Foundry MCP in regional Azure environments for fast, reliable access.
#    - **High Availability**:
#      - Ensures uptime and resilience with backup environments and distributed architecture.
#
# ---
#
# ### **13. Training, Evaluation, and Iteration**
#    - **Adaptive Evaluators**:
#      - Train agents iteratively through scoring mechanisms like relevance, coherence, or groundedness.
#    - **Fine-Tuning**:
#      - Use Foundry services to further adjust agent prompts and behaviors for task-specific refinements.
#
# ---
#
# ### **Examples of AI Agents You Can Build**
#    - **Customer Support Agent**:
#      - Multi-turn assistant capable of handling FAQs, complex workflows, and escalations.
#    - **Legal Document Reviewer**:
#      - Analyzes contracts and reviews amendments flagging inconsistencies.
#    - **Data Extraction Agent**:
#      - Extracts table entries and metadata from scanned documents or PDFs.
#    - **Knowledge Management Agent**:
#      - Integrates with enterprise knowledge bases for internal assistance.
#    - **Tool-Enhanced Agent**:
#      - Combines tasks like data enrichment, computation, or real-time API calls for workflow orchestration.
#
# ---
#
# ### How the MCP Server Supports Agent Development:
#    - Provides a **hosted environment** for developing and scaling agents with Azure's global infrastructure.
#    - Simplifies **schema definition**, version control, evaluations, and model integrations.
#    - Supports enterprise-grade **security** and **scalability**, enabling innovation at scale.
#
# Let me know if you need help designing or deploying an AI agent tailored to your use case!

# %% [markdown]
# ## 8. Cleanup
#
# Delete the agent when done to clean up resources.

# %%
# Cleanup: Delete the agent
print("🧹 Cleaning up resources...")

try:
    project_client.agents.delete_version(
        agent_name=agent.name,
        agent_version=agent.version
    )
    print(f"✅ Agent deleted: {agent.name} (Version: {agent.version})")
except Exception as e:
    print(f"⚠️ Error during cleanup: {e}")

print("\n🎉 MCP Tools notebook completed!")
# Out:
# 🧹 Cleaning up resources...
# ✅ Agent deleted: foundry-mcp-assistant (Version: 3)
#
# 🎉 MCP Tools notebook completed!

# %% [markdown]
# ## 📚 Summary
#
# In this notebook, we learned how to use the **Foundry MCP Server** to enhance AI agents with Foundry capabilities.
#
# ### Key Setup Steps:
#
# 1. **Configure in Portal**: Create MCP connection in Microsoft Foundry portal
# 2. **Get Connection ID**: Copy the connection ID from the portal
# 3. **Add to .env**: Set `FOUNDRY_MCP_CONNECTION_ID` in your environment
# 4. **Create Agent**: Use `MCPTool` with `project_connection_id`
#
# ### Key Concepts:
#
# | Concept | Description |
# |---------|-------------|
# | **Foundry MCP Server** | Cloud-hosted MCP service at `https://mcp.ai.azure.com` |
# | **MCPTool** | Tool configuration for connecting to the server |
# | **project_connection_id** | **Required** - Connection configured in Foundry portal |
# | **Entra ID Auth** | Secure authentication with user-specific permissions |
# | **Approval Flow** | Security feature requiring user consent |
#
# ### Foundry MCP Server Tool Categories:
#
# | Category | Example Tools | Use Cases |
# |----------|--------------|-----------|
# | **Models** | `model_catalog_list`, `model_deploy`, `model_quota_list` | Explore, compare, and deploy AI models |
# | **Evaluations** | `evaluation_create`, `evaluation_get` | Quality and safety assessments |
# | **Agents** | `agent_update`, `agent_list` | Agent lifecycle management |
# | **Knowledge** | `index_list`, `query_index` | Azure AI Search integration |
#
# ### Example Prompts for Foundry MCP Server:
#
# ```
# # Model Exploration
# "What OpenAI models are available in Microsoft Foundry?"
# "Compare Phi models and explain their differences"
# "What models are good for reasoning tasks?"
#
# # Deployment
# "What quota do I have available for GPT-4o?"
# "Help me deploy a model for my project"
#
# # Evaluation
# "How do I evaluate my agent's quality?"
# "What evaluators are available for text generation?"
#
# # General Use Cases
# "Recommend models for document analysis"
# "What models have appropriate licensing for enterprise use?"
# ```
#
# ### 🔐 Security Best Practices:
#
# - ✅ Foundry MCP Server uses **Entra ID authentication**
# - ✅ All operations run under **user's Azure RBAC permissions**
# - ✅ Every activity is **logged for auditing**
# - ✅ Use `require_approval="never"` for simpler demos, or `"always"` for production with manual approval
# - ✅ Tenant admins can enforce access via **Azure Policy**
#
# ### 🚀 Using Foundry MCP Server in VS Code
#
# You can also use Foundry MCP Server directly in VS Code with GitHub Copilot:
#
# 1. Open VS Code with GitHub Copilot enabled
# 2. Add to `.vscode/mcp.json`:
# ```json
# {
#   "servers": {
#     "foundry-mcp-remote": {
#       "type": "http",
#       "url": "https://mcp.ai.azure.com"
#     }
#   }
# }
# ```
# 3. Start chatting with Copilot using Foundry tools!
#
# ### 📚 Resources:
#
# - [Foundry MCP Server Documentation](https://learn.microsoft.com/azure/ai-foundry/mcp/get-started)
# - [Available Tools Reference](https://learn.microsoft.com/azure/ai-foundry/mcp/available-tools)
# - [Security Best Practices](https://learn.microsoft.com/azure/ai-foundry/mcp/security-best-practices)
# - [Microsoft Foundry Blog - MCP Announcement](https://devblogs.microsoft.com/foundry/announcing-foundry-mcp-server-preview-speeding-up-ai-dev-with-microsoft-foundry/)
# - [GitHub: mcp-foundry (legacy reference)](https://github.com/microsoft-foundry/mcp-foundry)
